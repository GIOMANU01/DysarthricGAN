# %%
import torch
import torch.nn as nn
import torchaudio
import torchaudio.transforms as T
from scipy.fftpack import dct 
import librosa
import numpy as np
import pandas as pd
import os
import soundfile as sf
import matplotlib.pyplot as plt


device = "cuda" if torch.cuda.is_available() else "cpu"
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ### GENERAZIONE DEI DISARTRICI

# %%
#struttra del generatore
class ResidualSumBlock(nn.Module):
    """
    Residual block che somma i flussi
    """
    def __init__(self, in_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, in_channels, 3, 1, 1)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(in_channels, in_channels, 3, 1, 1)
        self.bn2 = nn.BatchNorm2d(in_channels)

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += residual
        return self.relu(out)

class Generator(nn.Module):
    def __init__(self, in_channels=1, base_channels=8, num_res_blocks=3, residual_mode='sum'): # residual_mode = 'sum' or 'concat'
        super().__init__()

        self.input_conv = nn.Sequential(
            nn.Conv2d(in_channels, base_channels, 3, 1, 1),
            nn.ReLU(inplace=True)
        )
    
        self.res_blocks = nn.Sequential(*[ResidualSumBlock(base_channels) for _ in range(num_res_blocks)])
        self.output_conv = nn.Conv2d(base_channels, in_channels, 3, 1, 1)

    def forward(self, x):
        out = self.input_conv(x)
        out = self.res_blocks(out)
        out = self.output_conv(out)
        return out

# %%
input_path = "/home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/"
generator_path = "/home/deepfake/DysarthricGAN/M04/results_audio/004/generated_tensors/generated_melspec_495/generator_495.pth" # path del miglior generatore

# %%
#carico i pesi del generatore
generator = Generator(in_channels=1, residual_mode='sum').to(device) 
state_dict = torch.load(generator_path, map_location=device)
generator.load_state_dict(state_dict)
generator.eval()
# Out:
# /tmp/ipykernel_453247/3000352038.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(generator_path, map_location=device)
# Generator(
#   (input_conv): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualSumBlock(
#       (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResidualSumBlock(
#       (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResidualSumBlock(
#       (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (output_conv): Conv2d(8, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
for folder_name in os.listdir(input_path):
    folder_path = os.path.join(input_path, folder_name)
    out_folder = os.path.join(input_path, folder_name)

    print(f"\nElaborazione codice: {folder_name}")

    if not os.path.isdir(folder_path):
        print(f"Cartella non trovata: {folder_path}. Salto.")
        continue

    # Gestione di sano.pth ---
    sano_file = os.path.join(folder_path, "sano.pth")
    if os.path.exists(sano_file):
        try:
            print(f"  -> Caricamento: {sano_file}")
            # Carica il tensore e lo sposta sul device specificato
            sano_tensor = torch.load(sano_file, map_location=device)
            
            # Assicura che il tensore abbia almeno 4 dimensioni (Batch, Canali, Altezza, Larghezza)
            if sano_tensor.dim() == 3:
                sano_tensor = sano_tensor.unsqueeze(0) # Aggiunge dimensione batch
            
            # Esecuzione del generatore in modalità senza calcolo dei gradienti
            with torch.no_grad():
                gen_tensor = generator(sano_tensor)
            
            # Crea cartella di output se non esiste
            os.makedirs(out_folder, exist_ok=True)
            
            # Salva il tensore generato (riporta su CPU prima di salvare)
            out_file = os.path.join(out_folder, "dis_gen.pth")
            torch.save(gen_tensor.cpu(), out_file)
            print(f"Generato e salvato: {out_file}")
            
        except Exception as e:
            print(f"Errore elaborazione sano.pth in {folder_name}: {e}")
    else:
        print(f"File sano.pth non trovato in {folder_name}. Salto.")

print("\n Elaborazione completata per tutti i codici selezionati.")
# Out:
# ⚙️ Elaborazione codice: B2_UW42
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW42/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW42/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C12
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C12/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C12/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW51
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW51/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW51/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW63
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW63/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW63/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW61
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW61/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW61/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW23
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW23/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW23/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW67
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW67/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW67/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LJ
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LJ/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LJ/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW1
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW1/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW1/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW60
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW60/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW60/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW91
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW91/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW91/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW97
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW97/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW97/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW20
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW20/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW20/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW42
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW42/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW42/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C8
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C8/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C8/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW100
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW100/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW100/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW80
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW80/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW80/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW46
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW46/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW46/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C9
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C9/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C9/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW88
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW88/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW88/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_D1
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D1/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D1/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW76
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW76/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW76/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW37
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW37/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW37/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C13
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C13/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C13/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW29
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW29/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW29/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW55
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW55/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW55/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C13
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C13/sano.pth
# /tmp/ipykernel_453247/73223254.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sano_tensor = torch.load(sano_file, map_location=device)
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C13/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW96
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW96/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW96/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LV
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LV/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LV/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW13
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW13/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW13/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW10
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW10/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW10/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW65
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW65/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW65/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_D9
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D9/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D9/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C14
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C14/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C14/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW37
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW37/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW37/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW76
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW76/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW76/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW84
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW84/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW84/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C9
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C9/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C9/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C2
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C2/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C2/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW30
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW30/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW30/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LR
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LR/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LR/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW56
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW56/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW56/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW67
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW67/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW67/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW44
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW44/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW44/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW40
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW40/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW40/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW26
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW26/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW26/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW14
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW14/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW14/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW63
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW63/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW63/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LL
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LL/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LL/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW28
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW28/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW28/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW87
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW87/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW87/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW9
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW9/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW9/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C6
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C6/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C6/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_D8
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D8/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D8/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW14
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW14/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW14/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW40
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW40/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW40/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW51
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW51/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW51/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW88
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW88/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW88/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW10
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW10/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW10/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW20
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW20/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW20/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW40
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW40/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW40/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW69
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW69/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW69/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW7
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW7/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW7/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW59
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW59/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW59/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW78
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW78/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW78/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW14
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW14/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW14/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW61
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW61/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW61/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C18
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C18/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C18/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW59
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW59/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW59/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW92
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW92/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW92/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW11
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW11/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW11/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW58
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW58/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW58/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LD
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LD/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LD/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW80
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW80/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW80/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW46
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW46/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW46/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LU
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LU/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LU/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LM
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LM/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LM/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW83
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW83/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW83/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW6
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW6/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW6/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW58
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW58/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW58/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW92
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW92/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW92/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW48
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW48/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW48/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW45
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW45/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW45/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW96
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW96/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW96/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LT
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LT/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LT/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW42
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW42/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW42/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW64
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW64/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW64/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW8
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW8/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW8/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW18
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW18/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW18/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW71
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW71/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW71/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW32
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW32/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW32/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW87
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW87/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW87/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LG
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LG/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LG/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW41
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW41/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW41/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LI
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LI/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LI/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LP
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LP/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LP/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW66
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW66/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW66/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW40
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW40/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW40/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW39
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW39/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW39/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW10
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW10/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW10/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW4
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW4/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW4/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LR
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LR/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LR/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW31
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW31/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW31/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW64
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW64/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW64/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW70
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW70/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW70/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW30
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW30/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW30/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW100
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW100/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW100/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW68
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW68/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW68/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW17
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW17/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW17/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_D5
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D5/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D5/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_D0
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D0/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D0/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW95
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW95/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW95/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW32
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW32/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW32/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW20
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW20/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW20/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW7
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW7/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW7/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW87
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW87/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW87/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW2
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW2/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW2/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW50
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW50/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW50/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW22
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW22/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW22/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW38
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW38/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW38/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LW
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LW/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LW/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C11
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C11/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C11/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW88
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW88/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW88/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW90
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW90/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW90/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW57
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW57/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW57/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW74
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW74/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW74/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW63
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW63/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW63/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW56
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW56/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW56/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW24
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW24/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW24/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW42
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW42/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW42/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C5
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C5/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C5/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW57
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW57/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW57/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW86
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW86/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW86/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW27
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW27/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW27/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW8
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW8/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW8/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW93
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW93/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW93/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW49
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW49/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW49/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C13
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C13/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C13/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW98
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW98/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW98/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_D1
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_D1/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_D1/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LE
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LE/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LE/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW97
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW97/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW97/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C17
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C17/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C17/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW56
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW56/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW56/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LT
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LT/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LT/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_D0
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D0/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D0/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LV
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LV/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LV/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW78
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW78/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW78/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW38
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW38/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW38/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW50
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW50/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW50/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW71
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW71/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW71/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW37
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW37/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW37/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW72
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW72/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW72/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_D4
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D4/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D4/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW39
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW39/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW39/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW99
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW99/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW99/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW27
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW27/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW27/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW28
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW28/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW28/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW34
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW34/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW34/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW12
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW12/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW12/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW91
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW91/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW91/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_D8
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D8/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D8/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LX
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LX/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LX/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C18
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C18/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C18/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C6
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C6/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C6/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW25
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW25/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW25/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C5
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C5/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C5/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW21
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW21/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW21/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LB
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LB/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LB/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW62
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW62/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW62/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW33
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW33/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW33/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW58
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW58/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW58/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW29
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW29/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW29/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW61
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW61/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW61/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW54
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW54/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW54/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW37
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW37/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW37/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C4
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C4/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C4/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW68
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW68/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW68/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW69
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW69/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW69/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW22
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW22/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW22/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW8
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW8/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW8/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW36
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW36/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW36/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C9
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C9/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C9/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C15
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C15/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C15/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW79
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW79/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW79/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_D3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_D3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C19
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C19/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C19/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C1
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C1/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C1/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW24
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW24/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW24/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW96
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW96/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW96/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW88
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW88/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW88/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW64
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW64/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW64/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW12
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW12/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW12/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW22
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW22/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW22/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW23
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW23/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW23/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW21
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW21/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW21/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW81
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW81/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW81/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW81
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW81/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW81/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW69
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW69/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW69/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW49
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW49/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW49/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW32
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW32/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW32/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW4
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW4/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW4/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW84
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW84/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW84/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW88
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW88/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW88/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW100
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW100/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW100/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_C16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_C16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW62
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW62/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW62/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW91
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW91/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW91/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW56
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW56/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW56/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_D4
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_D4/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_D4/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW23
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW23/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW23/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW94
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW94/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW94/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW81
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW81/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW81/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW66
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW66/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW66/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW17
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW17/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW17/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW94
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW94/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW94/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW70
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW70/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW70/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW77
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW77/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW77/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW42
# ...
#
# ⚙️ Elaborazione codice: B2_UW7
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW7/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW7/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW35
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW35/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW35/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW24
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW24/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW24/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW91
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW91/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW91/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW79
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW79/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW79/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW79
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW79/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW79/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW12
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW12/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW12/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW65
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW65/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW65/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW28
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW28/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW28/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW76
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW76/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW76/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW41
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW41/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW41/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LY
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LY/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LY/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LU
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LU/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LU/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW97
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW97/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW97/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW64
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW64/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW64/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW54
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW54/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW54/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW74
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW74/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW74/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LS
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LS/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LS/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW17
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW17/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW17/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW68
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW68/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW68/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW44
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW44/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW44/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW18
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW18/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW18/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW93
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW93/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW93/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW85
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW85/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW85/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW89
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW89/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW89/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW70
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW70/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW70/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW31
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW31/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW31/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW29
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW29/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW29/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW35
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW35/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW35/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LJ
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LJ/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LJ/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_LZ
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LZ/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_LZ/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW94
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW94/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW94/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW71
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW71/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW71/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW26
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW26/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW26/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW35
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW35/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW35/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LH
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LH/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LH/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW84
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW84/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW84/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW75
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW75/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW75/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW34
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW34/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW34/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW40
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW40/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW40/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW78
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW78/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW78/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LT
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LT/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LT/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW91
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW91/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW91/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW47
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW47/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW47/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW6
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW6/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW6/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW85
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW85/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW85/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW36
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW36/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW36/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW49
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW49/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW49/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW100
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW100/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW100/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_UW48
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW48/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_UW48/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW43
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW43/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW43/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW54
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW54/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW54/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW73
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW73/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW73/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW62
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW62/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW62/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_UW63
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW63/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_UW63/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW31
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW31/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW31/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW72
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW72/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW72/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW95
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW95/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW95/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_D3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_D3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_D3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW6
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW6/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW6/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW16
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW16/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW16/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_LC
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LC/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_LC/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LN
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LN/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LN/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_LZ
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LZ/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_LZ/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_D3
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D3/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_D3/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW99
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW99/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW99/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW56
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW56/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW56/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW55
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW55/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW55/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_C19
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C19/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_C19/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW72
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW72/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW72/dis_gen.pth
#
# ⚙️ Elaborazione codice: B3_CW44
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW44/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B3_CW44/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW86
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW86/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW86/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW97
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW97/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW97/dis_gen.pth
#
# ⚙️ Elaborazione codice: B2_CW90
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW90/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B2_CW90/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_UW95
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW95/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_UW95/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_C6
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C6/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_C6/dis_gen.pth
#
# ⚙️ Elaborazione codice: B1_CW98
#   -> Caricamento: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW98/sano.pth
# ✅ Generato e salvato: /home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC/B1_CW98/dis_gen.pth
#
#
# 🏁 Elaborazione completata per tutti i codici selezionati.

# %% [markdown]
# ###  VOCODING (WAVEGLOW)

# %%
import torch
import torch.nn as nn
import numpy as np
import torchaudio
import torchaudio.transforms as T
import librosa
import numpy as np
import os
import soundfile as sf
import matplotlib.pyplot as plt
import sys
import glob
sys.path.append('/home/deepfake/DysarthricGAN')
from denoiser import Denoiser



device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Sampling rate del WAV originale
sr_orig = 22050

# Parametri mel-spectrogram generator
n_fft = 1024
hop_length = 256
win_length = 1024
n_mels = 80

# Parametri normalizzazione generator
mu_spk = -8.4277
sigma_spk = 3.399

# %%
input_path = "/home/deepfake/DysarthricGAN/M04/M04_MEL_SPEC" 
output_dir = "/home/deepfake/DysarthricGAN/patients_gen/M04_new_2" # La cartella dove salvare l'output WAV
os.makedirs(output_dir, exist_ok=True)

# %%
print("Caricamento WaveGlow...")
waveglow = torch.hub.load(
    'NVIDIA/DeepLearningExamples:torchhub',
    'nvidia_waveglow',
    model_math='fp32'
).to(device).eval()
waveglow = waveglow.remove_weightnorm(waveglow)
denoiser = Denoiser(waveglow).to(device)
print("WaveGlow caricato e pronto.")
# Out:
# Caricamento WaveGlow...
# Using cache found in /home/deepfake/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# /home/deepfake/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/deepfake/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/deepfake/miniconda3/envs/WG_PCC_env/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ✅ WaveGlow caricato e pronto.

# %%
for folder_name in os.listdir(input_path):
    folder_path = os.path.join(input_path, folder_name)

    if os.path.isdir(folder_path):
        
        # Definisci i percorsi I/O specifici
        mel_input_file = "dis_gen.pth"
        mel_input_path = os.path.join(folder_path, mel_input_file)
         
        
        output_wav_name = f"{folder_name}.wav" 
        output_wav_path = os.path.join(output_dir, output_wav_name)
        
    

        if not os.path.exists(mel_input_path):
            print(f"File {mel_input_file} non trovato in {folder_name}. Salto.")
            continue
        
        print(f"Elaborazione {folder_name} -> {output_wav_name} ---")

        # Carica il mel-spectrogram
        try:
            mel_generated = torch.load(mel_input_path, map_location=device)
        except Exception as e:
            print(f"Errore nel caricamento di {mel_input_path}: {e}")
            continue
        
        # Denormalizzazione 
        mel_generated = (mel_generated * sigma_spk) + mu_spk 
        
        # Adatta il tensor alla forma richiesta da WaveGlow
        mel_generated = mel_generated.squeeze(0).to(device)
        
        # Sintesi audio con WaveGlow
        with torch.no_grad():
            y_gen = waveglow.infer(mel_generated)
            # Applicazione Denoiser
            y_gen = denoiser(y_gen, strength=0.05)

        
        # Estrae il canale [0, 0, :] e converte in NumPy float32 1D
        y_gen = y_gen[0, 0, :].cpu().numpy().astype(np.float32)

        # Normalizzazione (clipping a 1.0)
        max_val = np.max(np.abs(y_gen))
        if max_val > 1.0:
            y_gen = y_gen / max_val
            
        # Salvataggio WAV
        sf.write(output_wav_path, y_gen, sr_orig)
        print(f" File WAV generato e salvato in: {output_wav_path}")

print("\nElaborazione batch completata")
# Out:
# --- Elaborazione B2_UW42 -> B2_UW42.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW42.wav
# --- Elaborazione B3_C12 -> B3_C12.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C12.wav
# --- Elaborazione B1_UW51 -> B1_UW51.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW51.wav
# --- Elaborazione B1_UW63 -> B1_UW63.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW63.wav
# --- Elaborazione B3_UW61 -> B3_UW61.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW61.wav
# --- Elaborazione B2_UW23 -> B2_UW23.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW23.wav
# --- Elaborazione B3_UW67 -> B3_UW67.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW67.wav
# --- Elaborazione B3_LJ -> B3_LJ.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LJ.wav
# --- Elaborazione B1_CW1 -> B1_CW1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW1.wav
# --- Elaborazione B2_CW60 -> B2_CW60.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW60.wav
# --- Elaborazione B3_CW91 -> B3_CW91.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW91.wav
# --- Elaborazione B2_CW97 -> B2_CW97.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW97.wav
# --- Elaborazione B2_UW20 -> B2_UW20.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW20.wav
# --- Elaborazione B3_UW42 -> B3_UW42.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW42.wav
# --- Elaborazione B3_C8 -> B3_C8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C8.wav
# --- Elaborazione B1_CW100 -> B1_CW100.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW100.wav
# --- Elaborazione B1_CW80 -> B1_CW80.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW80.wav
# --- Elaborazione B3_CW46 -> B3_CW46.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW46.wav
# --- Elaborazione B2_C9 -> B2_C9.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C9.wav
# --- Elaborazione B1_CW88 -> B1_CW88.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW88.wav
# --- Elaborazione B1_D1 -> B1_D1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D1.wav
# --- Elaborazione B3_UW76 -> B3_UW76.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW76.wav
# --- Elaborazione B3_CW37 -> B3_CW37.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW37.wav
# --- Elaborazione B1_C13 -> B1_C13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C13.wav
# --- Elaborazione B3_CW29 -> B3_CW29.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW29.wav
# --- Elaborazione B1_CW15 -> B1_CW15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW15.wav
# --- Elaborazione B2_UW15 -> B2_UW15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW15.wav
# --- Elaborazione B2_UW55 -> B2_UW55.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW55.wav
# --- Elaborazione B2_CW16 -> B2_CW16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW16.wav
# --- Elaborazione B2_C13 -> B2_C13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C13.wav
# --- Elaborazione B3_CW96 -> B3_CW96.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW96.wav
# --- Elaborazione B3_LV -> B3_LV.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LV.wav
# --- Elaborazione B3_UW13 -> B3_UW13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW13.wav
# --- Elaborazione B2_CW10 -> B2_CW10.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW10.wav
# --- Elaborazione B1_CW65 -> B1_CW65.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW65.wav
# --- Elaborazione B2_D9 -> B2_D9.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_D9.wav
# --- Elaborazione B2_C14 -> B2_C14.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C14.wav
# --- Elaborazione B3_UW37 -> B3_UW37.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW37.wav
# --- Elaborazione B3_CW76 -> B3_CW76.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW76.wav
# --- Elaborazione B2_CW84 -> B2_CW84.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW84.wav
# --- Elaborazione B3_C9 -> B3_C9.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C9.wav
# --- Elaborazione B1_C2 -> B1_C2.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C2.wav
# --- Elaborazione B3_CW30 -> B3_CW30.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW30.wav
# --- Elaborazione B1_LR -> B1_LR.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LR.wav
# --- Elaborazione B1_CW56 -> B1_CW56.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW56.wav
# --- Elaborazione B2_CW67 -> B2_CW67.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW67.wav
# --- Elaborazione B1_CW44 -> B1_CW44.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW44.wav
# --- Elaborazione B1_C15 -> B1_C15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C15.wav
# --- Elaborazione B3_UW40 -> B3_UW40.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW40.wav
# --- Elaborazione B2_CW26 -> B2_CW26.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW26.wav
# --- Elaborazione B2_UW14 -> B2_UW14.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW14.wav
# --- Elaborazione B2_CW63 -> B2_CW63.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW63.wav
# --- Elaborazione B1_LL -> B1_LL.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LL.wav
# --- Elaborazione B1_CW28 -> B1_CW28.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW28.wav
# --- Elaborazione B2_CW15 -> B2_CW15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW15.wav
# --- Elaborazione B2_C16 -> B2_C16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C16.wav
# --- Elaborazione B2_UW87 -> B2_UW87.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW87.wav
# --- Elaborazione B1_CW9 -> B1_CW9.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW9.wav
# --- Elaborazione B2_C6 -> B2_C6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C6.wav
# --- Elaborazione B1_D8 -> B1_D8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D8.wav
# --- Elaborazione B3_UW14 -> B3_UW14.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW14.wav
# --- Elaborazione B1_CW40 -> B1_CW40.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW40.wav
# --- Elaborazione B3_CW51 -> B3_CW51.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW51.wav
# --- Elaborazione B3_UW88 -> B3_UW88.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW88.wav
# --- Elaborazione B1_CW10 -> B1_CW10.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW10.wav
# --- Elaborazione B1_CW20 -> B1_CW20.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW20.wav
# --- Elaborazione B2_UW40 -> B2_UW40.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW40.wav
# --- Elaborazione B3_UW69 -> B3_UW69.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW69.wav
# --- Elaborazione B1_UW7 -> B1_UW7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW7.wav
# --- Elaborazione B3_UW59 -> B3_UW59.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW59.wav
# --- Elaborazione B3_UW78 -> B3_UW78.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW78.wav
# --- Elaborazione B1_UW14 -> B1_UW14.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW14.wav
# --- Elaborazione B1_UW61 -> B1_UW61.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW61.wav
# --- Elaborazione B1_C18 -> B1_C18.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C18.wav
# --- Elaborazione B3_CW59 -> B3_CW59.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW59.wav
# --- Elaborazione B1_CW92 -> B1_CW92.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW92.wav
# --- Elaborazione B2_UW11 -> B2_UW11.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW11.wav
# --- Elaborazione B2_UW58 -> B2_UW58.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW58.wav
# --- Elaborazione B2_LD -> B2_LD.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LD.wav
# --- Elaborazione B2_UW3 -> B2_UW3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW3.wav
# --- Elaborazione B1_UW80 -> B1_UW80.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW80.wav
# --- Elaborazione B2_CW46 -> B2_CW46.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW46.wav
# --- Elaborazione B1_LU -> B1_LU.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LU.wav
# --- Elaborazione B2_LM -> B2_LM.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LM.wav
# --- Elaborazione B1_UW83 -> B1_UW83.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW83.wav
# --- Elaborazione B2_CW6 -> B2_CW6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW6.wav
# --- Elaborazione B3_CW15 -> B3_CW15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW15.wav
# --- Elaborazione B3_CW58 -> B3_CW58.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW58.wav
# --- Elaborazione B1_UW92 -> B1_UW92.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW92.wav
# --- Elaborazione B2_UW48 -> B2_UW48.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW48.wav
# --- Elaborazione B3_CW45 -> B3_CW45.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW45.wav
# --- Elaborazione B3_UW16 -> B3_UW16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW16.wav
# --- Elaborazione B2_UW96 -> B2_UW96.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW96.wav
# --- Elaborazione B2_LT -> B2_LT.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LT.wav
# --- Elaborazione B1_CW42 -> B1_CW42.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW42.wav
# --- Elaborazione B1_UW64 -> B1_UW64.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW64.wav
# --- Elaborazione B3_CW8 -> B3_CW8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW8.wav
# --- Elaborazione B3_UW15 -> B3_UW15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW15.wav
# --- Elaborazione B1_CW18 -> B1_CW18.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW18.wav
# --- Elaborazione B1_CW3 -> B1_CW3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW3.wav
# --- Elaborazione B3_CW71 -> B3_CW71.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW71.wav
# --- Elaborazione B2_CW32 -> B2_CW32.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW32.wav
# --- Elaborazione B1_UW87 -> B1_UW87.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW87.wav
# --- Elaborazione B3_LG -> B3_LG.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LG.wav
# --- Elaborazione B2_CW41 -> B2_CW41.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW41.wav
# --- Elaborazione B1_LI -> B1_LI.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LI.wav
# --- Elaborazione B2_LP -> B2_LP.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LP.wav
# --- Elaborazione B1_CW66 -> B1_CW66.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW66.wav
# --- Elaborazione B2_CW40 -> B2_CW40.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW40.wav
# --- Elaborazione B1_UW39 -> B1_UW39.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW39.wav
# --- Elaborazione B2_UW10 -> B2_UW10.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW10.wav
# --- Elaborazione B3_UW4 -> B3_UW4.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW4.wav
# --- Elaborazione B2_LR -> B2_LR.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LR.wav
# --- Elaborazione B2_UW31 -> B2_UW31.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW31.wav
# --- Elaborazione B3_UW64 -> B3_UW64.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW64.wav
# --- Elaborazione B3_UW70 -> B3_UW70.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW70.wav
# --- Elaborazione B1_UW30 -> B1_UW30.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW30.wav
# --- Elaborazione B3_UW100 -> B3_UW100.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW100.wav
# --- Elaborazione B1_CW68 -> B1_CW68.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW68.wav
# --- Elaborazione B2_CW17 -> B2_CW17.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW17.wav
# --- Elaborazione B1_D5 -> B1_D5.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D5.wav
# --- Elaborazione B1_D0 -> B1_D0.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D0.wav
# --- Elaborazione B3_UW95 -> B3_UW95.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW95.wav
# --- Elaborazione B2_UW32 -> B2_UW32.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW32.wav
# --- Elaborazione B2_CW20 -> B2_CW20.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW20.wav
# --- Elaborazione B3_UW7 -> B3_UW7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW7.wav
# --- Elaborazione B1_CW87 -> B1_CW87.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW87.wav
# --- Elaborazione B1_CW2 -> B1_CW2.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW2.wav
# --- Elaborazione B1_CW50 -> B1_CW50.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW50.wav
# --- Elaborazione B3_UW22 -> B3_UW22.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW22.wav
# --- Elaborazione B2_CW38 -> B2_CW38.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW38.wav
# --- Elaborazione B3_LW -> B3_LW.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LW.wav
# --- Elaborazione B1_C11 -> B1_C11.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C11.wav
# --- Elaborazione B2_CW88 -> B2_CW88.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW88.wav
# --- Elaborazione B3_CW90 -> B3_CW90.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW90.wav
# --- Elaborazione B3_UW57 -> B3_UW57.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW57.wav
# --- Elaborazione B2_UW16 -> B2_UW16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW16.wav
# --- Elaborazione B2_CW74 -> B2_CW74.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW74.wav
# --- Elaborazione B3_CW63 -> B3_CW63.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW63.wav
# --- Elaborazione B3_CW56 -> B3_CW56.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW56.wav
# --- Elaborazione B3_UW24 -> B3_UW24.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW24.wav
# --- Elaborazione B2_CW42 -> B2_CW42.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW42.wav
# --- Elaborazione B3_C5 -> B3_C5.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C5.wav
# --- Elaborazione B2_CW57 -> B2_CW57.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW57.wav
# --- Elaborazione B3_CW86 -> B3_CW86.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW86.wav
# --- Elaborazione B3_UW27 -> B3_UW27.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW27.wav
# --- Elaborazione B2_UW8 -> B2_UW8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW8.wav
# --- Elaborazione B1_CW93 -> B1_CW93.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW93.wav
# --- Elaborazione B3_UW49 -> B3_UW49.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW49.wav
# --- Elaborazione B3_C13 -> B3_C13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C13.wav
# --- Elaborazione B2_CW98 -> B2_CW98.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW98.wav
# --- Elaborazione B3_D1 -> B3_D1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_D1.wav
# --- Elaborazione B2_LE -> B2_LE.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LE.wav
# --- Elaborazione B3_CW97 -> B3_CW97.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW97.wav
# --- Elaborazione B1_C17 -> B1_C17.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C17.wav
# --- Elaborazione B2_UW56 -> B2_UW56.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW56.wav
# --- Elaborazione B3_LT -> B3_LT.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LT.wav
# --- Elaborazione B2_D0 -> B2_D0.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_D0.wav
# --- Elaborazione B3_C15 -> B3_C15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C15.wav
# --- Elaborazione B2_LV -> B2_LV.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LV.wav
# --- Elaborazione B1_UW78 -> B1_UW78.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW78.wav
# --- Elaborazione B3_CW38 -> B3_CW38.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW38.wav
# --- Elaborazione B2_CW50 -> B2_CW50.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW50.wav
# --- Elaborazione B2_UW71 -> B2_UW71.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW71.wav
# --- Elaborazione B1_CW37 -> B1_CW37.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW37.wav
# --- Elaborazione B1_UW72 -> B1_UW72.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW72.wav
# --- Elaborazione B1_D4 -> B1_D4.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D4.wav
# --- Elaborazione B3_CW39 -> B3_CW39.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW39.wav
# --- Elaborazione B2_UW99 -> B2_UW99.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW99.wav
# --- Elaborazione B1_UW27 -> B1_UW27.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW27.wav
# --- Elaborazione B3_UW28 -> B3_UW28.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW28.wav
# --- Elaborazione B3_CW34 -> B3_CW34.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW34.wav
# --- Elaborazione B1_CW12 -> B1_CW12.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW12.wav
# --- Elaborazione B3_UW3 -> B3_UW3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW3.wav
# --- Elaborazione B1_UW91 -> B1_UW91.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW91.wav
# --- Elaborazione B2_D8 -> B2_D8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_D8.wav
# --- Elaborazione B3_LX -> B3_LX.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LX.wav
# --- Elaborazione B2_C18 -> B2_C18.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C18.wav
# --- Elaborazione B3_C6 -> B3_C6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C6.wav
# --- Elaborazione B3_UW25 -> B3_UW25.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW25.wav
# --- Elaborazione B2_C5 -> B2_C5.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C5.wav
# --- Elaborazione B2_CW21 -> B2_CW21.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW21.wav
# --- Elaborazione B2_LB -> B2_LB.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LB.wav
# --- Elaborazione B1_UW62 -> B1_UW62.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW62.wav
# --- Elaborazione B3_CW3 -> B3_CW3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW3.wav
# --- Elaborazione B3_CW33 -> B3_CW33.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW33.wav
# --- Elaborazione B1_C3 -> B1_C3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C3.wav
# --- Elaborazione B2_CW58 -> B2_CW58.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW58.wav
# --- Elaborazione B1_CW29 -> B1_CW29.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW29.wav
# --- Elaborazione B2_CW61 -> B2_CW61.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW61.wav
# --- Elaborazione B3_CW54 -> B3_CW54.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW54.wav
# --- Elaborazione B2_UW37 -> B2_UW37.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW37.wav
# --- Elaborazione B2_C4 -> B2_C4.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C4.wav
# --- Elaborazione B3_CW68 -> B3_CW68.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW68.wav
# --- Elaborazione B1_UW69 -> B1_UW69.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW69.wav
# --- Elaborazione B1_UW22 -> B1_UW22.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW22.wav
# --- Elaborazione B2_CW8 -> B2_CW8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW8.wav
# --- Elaborazione B2_UW36 -> B2_UW36.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW36.wav
# --- Elaborazione B1_C9 -> B1_C9.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C9.wav
# --- Elaborazione B2_C15 -> B2_C15.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C15.wav
# --- Elaborazione B1_UW79 -> B1_UW79.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW79.wav
# --- Elaborazione B1_D3 -> B1_D3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D3.wav
# --- Elaborazione B3_C19 -> B3_C19.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C19.wav
# --- Elaborazione B1_C1 -> B1_C1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C1.wav
# --- Elaborazione B3_CW24 -> B3_CW24.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW24.wav
# --- Elaborazione B1_UW96 -> B1_UW96.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW96.wav
# --- Elaborazione B2_UW88 -> B2_UW88.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW88.wav
# --- Elaborazione B2_CW64 -> B2_CW64.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW64.wav
# --- Elaborazione B2_CW12 -> B2_CW12.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW12.wav
# --- Elaborazione B3_CW22 -> B3_CW22.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW22.wav
# --- Elaborazione B1_UW23 -> B1_UW23.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW23.wav
# --- Elaborazione B1_CW21 -> B1_CW21.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW21.wav
# --- Elaborazione B3_UW81 -> B3_UW81.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW81.wav
# --- Elaborazione B1_UW81 -> B1_UW81.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW81.wav
# --- Elaborazione B3_CW69 -> B3_CW69.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW69.wav
# --- Elaborazione B3_CW49 -> B3_CW49.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW49.wav
# --- Elaborazione B3_CW32 -> B3_CW32.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW32.wav
# --- Elaborazione B1_CW4 -> B1_CW4.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW4.wav
# --- Elaborazione B3_CW84 -> B3_CW84.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW84.wav
# --- Elaborazione B1_UW88 -> B1_UW88.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW88.wav
# --- Elaborazione B1_UW100 -> B1_UW100.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW100.wav
# --- Elaborazione B3_C16 -> B3_C16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C16.wav
# --- Elaborazione B3_CW62 -> B3_CW62.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW62.wav
# --- Elaborazione B3_UW91 -> B3_UW91.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW91.wav
# --- Elaborazione B2_CW56 -> B2_CW56.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW56.wav
# --- Elaborazione B3_D4 -> B3_D4.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_D4.wav
# --- Elaborazione B2_CW23 -> B2_CW23.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW23.wav
# --- Elaborazione B3_CW94 -> B3_CW94.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW94.wav
# --- Elaborazione B1_CW81 -> B1_CW81.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW81.wav
# --- Elaborazione B2_CW66 -> B2_CW66.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW66.wav
# --- Elaborazione B1_UW17 -> B1_UW17.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW17.wav
# --- Elaborazione B1_CW94 -> B1_CW94.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW94.wav
# --- Elaborazione B2_UW70 -> B2_UW70.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW70.wav
# --- Elaborazione B3_UW77 -> B3_UW77.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW77.wav
# --- Elaborazione B1_UW42 -> B1_UW42.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW42.wav
# --- Elaborazione B1_UW54 -> B1_UW54.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW54.wav
# --- Elaborazione B2_C1 -> B2_C1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C1.wav
# --- Elaborazione B2_UW94 -> B2_UW94.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW94.wav
# --- Elaborazione B1_UW43 -> B1_UW43.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW43.wav
# --- Elaborazione B3_LA -> B3_LA.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LA.wav
# --- Elaborazione B1_LJ -> B1_LJ.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LJ.wav
# --- Elaborazione B2_C11 -> B2_C11.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C11.wav
# --- Elaborazione B2_CW31 -> B2_CW31.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW31.wav
# --- Elaborazione B3_C1 -> B3_C1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C1.wav
# --- Elaborazione B2_UW13 -> B2_UW13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW13.wav
# --- Elaborazione B2_LY -> B2_LY.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LY.wav
# --- Elaborazione B3_UW47 -> B3_UW47.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW47.wav
# --- Elaborazione B2_CW73 -> B2_CW73.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW73.wav
# --- Elaborazione B3_UW56 -> B3_UW56.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW56.wav
# --- Elaborazione B1_UW86 -> B1_UW86.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW86.wav
# --- Elaborazione B1_LZ -> B1_LZ.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LZ.wav
# --- Elaborazione B3_C7 -> B3_C7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_C7.wav
# --- Elaborazione B1_CW73 -> B1_CW73.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW73.wav
# --- Elaborazione B1_UW68 -> B1_UW68.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW68.wav
# --- Elaborazione B3_CW99 -> B3_CW99.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW99.wav
# --- Elaborazione B3_CW92 -> B3_CW92.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW92.wav
# --- Elaborazione B3_D0 -> B3_D0.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_D0.wav
# --- Elaborazione B1_UW8 -> B1_UW8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW8.wav
# --- Elaborazione B3_UW90 -> B3_UW90.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW90.wav
# --- Elaborazione B3_UW50 -> B3_UW50.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW50.wav
# --- Elaborazione B2_UW89 -> B2_UW89.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW89.wav
# --- Elaborazione B2_LA -> B2_LA.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LA.wav
# --- Elaborazione B2_UW61 -> B2_UW61.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW61.wav
# --- Elaborazione B1_CW95 -> B1_CW95.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW95.wav
# --- Elaborazione B3_LC -> B3_LC.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LC.wav
# --- Elaborazione B2_UW49 -> B2_UW49.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW49.wav
# --- Elaborazione B2_CW4 -> B2_CW4.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW4.wav
# --- Elaborazione B3_UW12 -> B3_UW12.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW12.wav
# --- Elaborazione B2_LG -> B2_LG.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LG.wav
# --- Elaborazione B2_UW38 -> B2_UW38.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW38.wav
# --- Elaborazione B1_UW34 -> B1_UW34.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW34.wav
# --- Elaborazione B2_UW28 -> B2_UW28.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW28.wav
# --- Elaborazione B1_UW1 -> B1_UW1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW1.wav
# --- Elaborazione B2_CW30 -> B2_CW30.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW30.wav
# --- Elaborazione B1_CW5 -> B1_CW5.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW5.wav
# --- Elaborazione B3_CW88 -> B3_CW88.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW88.wav
# --- Elaborazione B2_D2 -> B2_D2.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_D2.wav
# --- Elaborazione B3_D7 -> B3_D7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_D7.wav
# --- Elaborazione B1_CW96 -> B1_CW96.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW96.wav
# --- Elaborazione B1_CW71 -> B1_CW71.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW71.wav
# --- Elaborazione B3_LK -> B3_LK.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LK.wav
# --- Elaborazione B2_UW84 -> B2_UW84.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW84.wav
# --- Elaborazione B1_CW90 -> B1_CW90.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW90.wav
# --- Elaborazione B3_CW95 -> B3_CW95.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW95.wav
# --- Elaborazione B3_CW64 -> B3_CW64.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW64.wav
# --- Elaborazione B1_CW63 -> B1_CW63.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW63.wav
# --- Elaborazione B3_CW93 -> B3_CW93.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW93.wav
# --- Elaborazione B1_CW39 -> B1_CW39.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW39.wav
# --- Elaborazione B3_UW1 -> B3_UW1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW1.wav
# --- Elaborazione B3_UW84 -> B3_UW84.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW84.wav
# --- Elaborazione B2_CW48 -> B2_CW48.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW48.wav
# --- Elaborazione B3_UW30 -> B3_UW30.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW30.wav
# --- Elaborazione B1_CW7 -> B1_CW7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW7.wav
# --- Elaborazione B1_CW13 -> B1_CW13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW13.wav
# --- Elaborazione B1_D2 -> B1_D2.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D2.wav
# --- Elaborazione B1_UW48 -> B1_UW48.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW48.wav
# --- Elaborazione B1_LE -> B1_LE.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LE.wav
# --- Elaborazione B2_UW75 -> B2_UW75.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW75.wav
# --- Elaborazione B3_UW51 -> B3_UW51.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW51.wav
# --- Elaborazione B3_CW42 -> B3_CW42.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW42.wav
# --- Elaborazione B1_UW11 -> B1_UW11.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW11.wav
# --- Elaborazione B2_LW -> B2_LW.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LW.wav
# --- Elaborazione B3_CW13 -> B3_CW13.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW13.wav
# --- Elaborazione B3_UW85 -> B3_UW85.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW85.wav
# --- Elaborazione B2_CW83 -> B2_CW83.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW83.wav
# --- Elaborazione B3_CW72 -> B3_CW72.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW72.wav
# --- Elaborazione B3_CW27 -> B3_CW27.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW27.wav
# --- Elaborazione B2_CW87 -> B2_CW87.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW87.wav
# --- Elaborazione B2_LL -> B2_LL.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LL.wav
# --- Elaborazione B2_CW1 -> B2_CW1.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW1.wav
# --- Elaborazione B2_CW51 -> B2_CW51.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW51.wav
# --- Elaborazione B3_CW50 -> B3_CW50.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW50.wav
# --- Elaborazione B3_CW60 -> B3_CW60.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW60.wav
# --- Elaborazione B3_UW65 -> B3_UW65.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW65.wav
# --- Elaborazione B2_CW52 -> B2_CW52.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW52.wav
# --- Elaborazione B3_LR -> B3_LR.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LR.wav
# --- Elaborazione B1_CW17 -> B1_CW17.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW17.wav
# --- Elaborazione B3_CW52 -> B3_CW52.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW52.wav
# --- Elaborazione B3_UW38 -> B3_UW38.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW38.wav
# --- Elaborazione B1_CW59 -> B1_CW59.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW59.wav
# --- Elaborazione B2_UW74 -> B2_UW74.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW74.wav
# --- Elaborazione B1_CW47 -> B1_CW47.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW47.wav
# --- Elaborazione B1_LW -> B1_LW.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LW.wav
# --- Elaborazione B1_C16 -> B1_C16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C16.wav
# --- Elaborazione B1_UW36 -> B1_UW36.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW36.wav
# --- Elaborazione B2_LN -> B2_LN.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LN.wav
# --- Elaborazione B1_CW6 -> B1_CW6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW6.wav
# --- Elaborazione B2_UW22 -> B2_UW22.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW22.wav
# --- Elaborazione B1_LN -> B1_LN.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LN.wav
# --- Elaborazione B2_CW44 -> B2_CW44.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW44.wav
# --- Elaborazione B3_CW20 -> B3_CW20.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW20.wav
# --- Elaborazione B1_UW18 -> B1_UW18.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW18.wav
# --- Elaborazione B1_D7 -> B1_D7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_D7.wav
# --- Elaborazione B1_CW55 -> B1_CW55.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW55.wav
# --- Elaborazione B3_UW53 -> B3_UW53.wav ---
# ...
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW66.wav
# --- Elaborazione B1_LV -> B1_LV.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LV.wav
# --- Elaborazione B2_UW29 -> B2_UW29.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW29.wav
# --- Elaborazione B3_CW43 -> B3_CW43.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW43.wav
# --- Elaborazione B3_UW98 -> B3_UW98.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW98.wav
# --- Elaborazione B3_LE -> B3_LE.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LE.wav
# --- Elaborazione B2_UW81 -> B2_UW81.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW81.wav
# --- Elaborazione B3_UW23 -> B3_UW23.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW23.wav
# --- Elaborazione B1_LP -> B1_LP.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LP.wav
# --- Elaborazione B1_CW54 -> B1_CW54.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW54.wav
# --- Elaborazione B2_CW93 -> B2_CW93.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW93.wav
# --- Elaborazione B1_UW94 -> B1_UW94.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW94.wav
# --- Elaborazione B1_UW70 -> B1_UW70.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW70.wav
# --- Elaborazione B1_CW8 -> B1_CW8.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW8.wav
# --- Elaborazione B1_UW85 -> B1_UW85.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW85.wav
# --- Elaborazione B2_UW47 -> B2_UW47.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW47.wav
# --- Elaborazione B2_UW83 -> B2_UW83.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW83.wav
# --- Elaborazione B1_UW28 -> B1_UW28.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW28.wav
# --- Elaborazione B3_CW74 -> B3_CW74.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW74.wav
# --- Elaborazione B2_CW80 -> B2_CW80.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW80.wav
# --- Elaborazione B2_UW86 -> B2_UW86.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW86.wav
# --- Elaborazione B3_UW86 -> B3_UW86.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW86.wav
# --- Elaborazione B2_C3 -> B2_C3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C3.wav
# --- Elaborazione B2_C10 -> B2_C10.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C10.wav
# --- Elaborazione B1_UW25 -> B1_UW25.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW25.wav
# --- Elaborazione B3_CW85 -> B3_CW85.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW85.wav
# --- Elaborazione B1_UW90 -> B1_UW90.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW90.wav
# --- Elaborazione B1_UW47 -> B1_UW47.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW47.wav
# --- Elaborazione B2_CW19 -> B2_CW19.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW19.wav
# --- Elaborazione B1_CW30 -> B1_CW30.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW30.wav
# --- Elaborazione B2_LI -> B2_LI.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LI.wav
# --- Elaborazione B1_LM -> B1_LM.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LM.wav
# --- Elaborazione B2_UW7 -> B2_UW7.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW7.wav
# --- Elaborazione B2_CW35 -> B2_CW35.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW35.wav
# --- Elaborazione B1_CW24 -> B1_CW24.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW24.wav
# --- Elaborazione B1_CW91 -> B1_CW91.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW91.wav
# --- Elaborazione B2_UW79 -> B2_UW79.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW79.wav
# --- Elaborazione B3_CW79 -> B3_CW79.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW79.wav
# --- Elaborazione B1_UW12 -> B1_UW12.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW12.wav
# --- Elaborazione B2_CW65 -> B2_CW65.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW65.wav
# --- Elaborazione B3_CW28 -> B3_CW28.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW28.wav
# --- Elaborazione B1_CW76 -> B1_CW76.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW76.wav
# --- Elaborazione B1_UW41 -> B1_UW41.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW41.wav
# --- Elaborazione B1_LY -> B1_LY.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LY.wav
# --- Elaborazione B3_LU -> B3_LU.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LU.wav
# --- Elaborazione B1_UW97 -> B1_UW97.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW97.wav
# --- Elaborazione B1_CW64 -> B1_CW64.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW64.wav
# --- Elaborazione B3_UW54 -> B3_UW54.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW54.wav
# --- Elaborazione B1_UW74 -> B1_UW74.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW74.wav
# --- Elaborazione B1_LS -> B1_LS.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LS.wav
# --- Elaborazione B3_UW17 -> B3_UW17.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW17.wav
# --- Elaborazione B2_CW68 -> B2_CW68.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW68.wav
# --- Elaborazione B2_UW44 -> B2_UW44.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW44.wav
# --- Elaborazione B2_CW18 -> B2_CW18.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW18.wav
# --- Elaborazione B2_UW93 -> B2_UW93.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW93.wav
# --- Elaborazione B2_UW85 -> B2_UW85.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW85.wav
# --- Elaborazione B3_CW89 -> B3_CW89.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW89.wav
# --- Elaborazione B1_CW70 -> B1_CW70.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW70.wav
# --- Elaborazione B3_UW31 -> B3_UW31.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW31.wav
# --- Elaborazione B3_UW29 -> B3_UW29.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW29.wav
# --- Elaborazione B3_UW35 -> B3_UW35.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW35.wav
# --- Elaborazione B2_LJ -> B2_LJ.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LJ.wav
# --- Elaborazione B2_LZ -> B2_LZ.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_LZ.wav
# --- Elaborazione B3_UW94 -> B3_UW94.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW94.wav
# --- Elaborazione B1_UW71 -> B1_UW71.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW71.wav
# --- Elaborazione B1_UW26 -> B1_UW26.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW26.wav
# --- Elaborazione B3_CW35 -> B3_CW35.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW35.wav
# --- Elaborazione B3_LH -> B3_LH.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LH.wav
# --- Elaborazione B1_UW84 -> B1_UW84.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW84.wav
# --- Elaborazione B2_CW75 -> B2_CW75.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW75.wav
# --- Elaborazione B1_CW34 -> B1_CW34.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW34.wav
# --- Elaborazione B3_CW40 -> B3_CW40.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW40.wav
# --- Elaborazione B1_CW16 -> B1_CW16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW16.wav
# --- Elaborazione B3_CW78 -> B3_CW78.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW78.wav
# --- Elaborazione B1_LT -> B1_LT.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LT.wav
# --- Elaborazione B2_CW91 -> B2_CW91.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW91.wav
# --- Elaborazione B2_CW47 -> B2_CW47.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW47.wav
# --- Elaborazione B3_UW6 -> B3_UW6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW6.wav
# --- Elaborazione B1_CW85 -> B1_CW85.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW85.wav
# --- Elaborazione B3_UW36 -> B3_UW36.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW36.wav
# --- Elaborazione B1_UW49 -> B1_UW49.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW49.wav
# --- Elaborazione B3_CW100 -> B3_CW100.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW100.wav
# --- Elaborazione B3_UW48 -> B3_UW48.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_UW48.wav
# --- Elaborazione B2_CW43 -> B2_CW43.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW43.wav
# --- Elaborazione B2_UW54 -> B2_UW54.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW54.wav
# --- Elaborazione B2_UW73 -> B2_UW73.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW73.wav
# --- Elaborazione B1_CW62 -> B1_CW62.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW62.wav
# --- Elaborazione B2_UW63 -> B2_UW63.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_UW63.wav
# --- Elaborazione B2_CW3 -> B2_CW3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW3.wav
# --- Elaborazione B1_CW31 -> B1_CW31.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW31.wav
# --- Elaborazione B1_CW72 -> B1_CW72.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW72.wav
# --- Elaborazione B2_CW95 -> B2_CW95.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW95.wav
# --- Elaborazione B3_D3 -> B3_D3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_D3.wav
# --- Elaborazione B1_UW6 -> B1_UW6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW6.wav
# --- Elaborazione B1_UW16 -> B1_UW16.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW16.wav
# --- Elaborazione B1_LC -> B1_LC.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_LC.wav
# --- Elaborazione B3_LN -> B3_LN.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LN.wav
# --- Elaborazione B3_LZ -> B3_LZ.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_LZ.wav
# --- Elaborazione B2_D3 -> B2_D3.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_D3.wav
# --- Elaborazione B2_CW99 -> B2_CW99.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW99.wav
# --- Elaborazione B1_UW56 -> B1_UW56.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW56.wav
# --- Elaborazione B2_CW55 -> B2_CW55.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW55.wav
# --- Elaborazione B2_C19 -> B2_C19.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_C19.wav
# --- Elaborazione B2_CW72 -> B2_CW72.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW72.wav
# --- Elaborazione B3_CW44 -> B3_CW44.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B3_CW44.wav
# --- Elaborazione B2_CW86 -> B2_CW86.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW86.wav
# --- Elaborazione B1_CW97 -> B1_CW97.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW97.wav
# --- Elaborazione B2_CW90 -> B2_CW90.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B2_CW90.wav
# --- Elaborazione B1_UW95 -> B1_UW95.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_UW95.wav
# --- Elaborazione B1_C6 -> B1_C6.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_C6.wav
# --- Elaborazione B1_CW98 -> B1_CW98.wav ---
#    ✅ File WAV generato e salvato in: /home/deepfake/DysarthricGAN/patients_gen/M04_new_2/B1_CW98.wav
#
# --- Elaborazione batch completata ---
