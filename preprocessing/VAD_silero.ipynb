# %%
import sys
# !{sys.executable} -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !{sys.executable} -m pip install silero-vad pandas pydub openpyxl
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (0.23.0)
# Requirement already satisfied: torchaudio in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (2.8.0)
# Requirement already satisfied: jinja2 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: filelock in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: fsspec in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch) (2025.5.1)
# Requirement already satisfied: networkx in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\gioel\appdata\roaming\python\python310\site-packages (from torch) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: numpy in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: silero-vad in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (6.0.0)
# Requirement already satisfied: pandas in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: pydub in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (0.25.1)
# Requirement already satisfied: openpyxl in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: torch>=1.12.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from silero-vad) (2.8.0)
# Requirement already satisfied: torchaudio>=0.12.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from silero-vad) (2.8.0)
# Requirement already satisfied: onnxruntime>=1.16.1 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from silero-vad) (1.23.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gioel\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: et-xmlfile in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: sympy in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad) (1.14.0)
# Requirement already satisfied: protobuf in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad) (5.29.5)
# Requirement already satisfied: flatbuffers in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad) (25.9.23)
# Requirement already satisfied: packaging in c:\users\gioel\appdata\roaming\python\python310\site-packages (from onnxruntime>=1.16.1->silero-vad) (25.0)
# Requirement already satisfied: coloredlogs in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad) (15.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\gioel\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\gioel\appdata\roaming\python\python310\site-packages (from torch>=1.12.0->silero-vad) (4.14.0)
# Requirement already satisfied: filelock in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad) (3.18.0)
# Requirement already satisfied: fsspec in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad) (2025.5.1)
# Requirement already satisfied: networkx in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.16.1->silero-vad) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.16.1->silero-vad) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.12.0->silero-vad) (3.0.2)
# Requirement already satisfied: pyreadline3 in c:\users\gioel\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.16.1->silero-vad) (3.5.4)
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from pydub import AudioSegment
from pathlib import Path
import pandas as pd
from silero_vad import VADIterator
import os
import librosa
# Out:
# c:\Users\gioel\AppData\Local\Programs\Python\Python310\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
def merge_close_segments(segments, max_silence_sec=5, sr=16000):
    merged = []
    for seg in segments:
        if not merged:
            merged.append(seg)
        else:
            prev = merged[-1]
            # se la pausa tra prev ed attuale è minore di max_silence_sec, uniscili
            if (seg['start'] - prev['end']) / sr <= max_silence_sec:
                prev['end'] = seg['end']
            else:
                merged.append(seg)
    return merged

# %%
# CONFIGURAZIONE
# ================================================
input_dir = Path("C:/Users/gioel/Desktop/patient_GAN_vad/control_CM08/pre_vad/")
output_dir = Path("C:/Users/gioel/Desktop/patient_GAN_vad/control_CM08/")
output_dir.mkdir(exist_ok=True)
sr = 16000
results = []
failed_files = []

# %%
device = 'cpu'  # CPU-only
model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad', model='silero_vad', force_reload=False)
(get_speech_timestamps, _, read_audio, _, _) = utils
vad_iterator = VADIterator(model, sampling_rate=sr)
# Out:
# Using cache found in C:\Users\gioel/.cache\torch\hub\snakers4_silero-vad_master

# %%
def sec_to_minsec(sec):
    m = int(sec // 60)
    s = int(sec % 60)
    return f"{m}.{s:02d}"

# %%
for subfolder in input_dir.iterdir():
    if subfolder.is_dir():
        for wav_file in subfolder.glob("*.wav"):
            waveform = read_audio(str(wav_file), sampling_rate=sr) 
             
            # Ottieni segmenti VAD 
            speech_timestamps = get_speech_timestamps(waveform, model, sampling_rate=sr, threshold=0.3)

            if not speech_timestamps:
                failed_files.append({'file': wav_file.name, 'path': str(wav_file)})
                continue
            
             # Unisci segmenti separati da silenzi brevi
            speech_timestamps = merge_close_segments(speech_timestamps, max_silence_sec=5, sr=sr)
            
            # Calcola probabilità per chunk per ciascun segmento
            for seg in speech_timestamps:
                start_sample = seg['start']
                end_sample = seg['end']
                segment_waveform = waveform[start_sample:end_sample]

                # Calcola probabilità a chunk
                speech_probs = []
                window_size_samples = 512 if sr == 16000 else 256
                for i in range(0, len(segment_waveform), window_size_samples):
                    chunk = segment_waveform[i:i+window_size_samples]
                    if len(chunk) < window_size_samples:
                        break
                    prob = model(chunk, sr).item()
                    speech_probs.append(prob)
                vad_iterator.reset_states()  # reset tra segmenti

                # Aggiungi score medio al segmento
                seg['speech_prob'] = speech_probs
                seg['score'] = sum(speech_probs)/len(speech_probs) if speech_probs else 0

            audio = AudioSegment.from_file(wav_file)
            
            # Salva ogni segmento e aggiungi info per Excel
            for i, seg in enumerate(speech_timestamps, start=1):
                start_ms = int(seg['start'] / sr * 1000)
                end_ms = int(seg['end'] / sr * 1000)
                score = sum(seg['speech_prob']) / len(seg['speech_prob'])
                clip = audio[start_ms:end_ms]

                # Salva segmento
                out_subdir = output_dir / subfolder.name
                out_subdir.mkdir(exist_ok=True)
                out_path = out_subdir / f"{wav_file.stem}_segment{i}.wav"
                clip.export(out_path, format="wav")

                # Calcola durata in secondi e minuti.secondi
                duration_sec = (end_ms - start_ms) / 1000
                duration_minsec = sec_to_minsec(duration_sec)

                # Aggiungi al dataframe
                results.append({
                    'file': wav_file.name,
                    'segment': i,
                    'start_sec': start_ms/1000,
                    'end_sec': end_ms/1000,
                    'duration_sec': duration_sec,
                    'duration_min.sec': duration_minsec,
                    'score': seg['score'],
                })
# Out:
# c:\Users\gioel\AppData\Local\Programs\Python\Python310\lib\site-packages\silero_vad\utils_vad.py:139: UserWarning: torchaudio._backend.list_audio_backends has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   list_backends = torchaudio.list_audio_backends()
# c:\Users\gioel\AppData\Local\Programs\Python\Python310\lib\site-packages\silero_vad\utils_vad.py:150: UserWarning: torchaudio.sox_effects.sox_effects.apply_effects_file has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   wav, sr = torchaudio.sox_effects.apply_effects_file(path, effects=effects)
# c:\Users\gioel\AppData\Local\Programs\Python\Python310\lib\site-packages\torchaudio\_backend\utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(

# %%
# SALVA EXCEL
# ================================================
df = pd.DataFrame(results)
df.to_excel(output_dir / "vad_segments.xlsx", index=False)

df_failed = pd.DataFrame(failed_files)
df_failed.to_excel(output_dir / "VAD_failed_files.xlsx", index=False)
print(f"✅ VAD completato. Excel salvato in: {output_dir / 'vad_segments.xlsx'}")
# Out:
# ✅ VAD completato. Excel salvato in: C:\Users\gioel\Desktop\patient_GAN_vad\control_CM08\vad_segments.xlsx

# %%
# Percorso della cartella contenente i file
cartella = "C:/Users/gioel/Desktop/patient_GAN_vad/patient_M08/M08"  # Sostituisci con il tuo percorso

# Ciclo su tutti i file nella cartella
for filename in os.listdir(cartella):
    if filename.endswith(".wav") and "_segment1" in filename:
        nuovo_nome = filename.replace("_segment1", "")
        vecchio_percorso = os.path.join(cartella, filename)
        nuovo_percorso = os.path.join(cartella, nuovo_nome)
        os.rename(vecchio_percorso, nuovo_percorso)
        print(f"Rinominato: {filename} -> {nuovo_nome}")
# Out:
# Rinominato: B1_C10_segment1.wav -> B1_C10.wav
# Rinominato: B1_C11_segment1.wav -> B1_C11.wav
# Rinominato: B1_C12_segment1.wav -> B1_C12.wav
# Rinominato: B1_C13_segment1.wav -> B1_C13.wav
# Rinominato: B1_C14_segment1.wav -> B1_C14.wav
# Rinominato: B1_C15_segment1.wav -> B1_C15.wav
# Rinominato: B1_C16_segment1.wav -> B1_C16.wav
# Rinominato: B1_C17_segment1.wav -> B1_C17.wav
# Rinominato: B1_C18_segment1.wav -> B1_C18.wav
# Rinominato: B1_C19_segment1.wav -> B1_C19.wav
# Rinominato: B1_C1_segment1.wav -> B1_C1.wav
# Rinominato: B1_C2_segment1.wav -> B1_C2.wav
# Rinominato: B1_C3_segment1.wav -> B1_C3.wav
# Rinominato: B1_C4_segment1.wav -> B1_C4.wav
# Rinominato: B1_C5_segment1.wav -> B1_C5.wav
# Rinominato: B1_C6_segment1.wav -> B1_C6.wav
# Rinominato: B1_C7_segment1.wav -> B1_C7.wav
# Rinominato: B1_C8_segment1.wav -> B1_C8.wav
# Rinominato: B1_C9_segment1.wav -> B1_C9.wav
# Rinominato: B1_CW100_segment1.wav -> B1_CW100.wav
# Rinominato: B1_CW10_segment1.wav -> B1_CW10.wav
# Rinominato: B1_CW11_segment1.wav -> B1_CW11.wav
# Rinominato: B1_CW12_segment1.wav -> B1_CW12.wav
# Rinominato: B1_CW13_segment1.wav -> B1_CW13.wav
# Rinominato: B1_CW14_segment1.wav -> B1_CW14.wav
# Rinominato: B1_CW15_segment1.wav -> B1_CW15.wav
# Rinominato: B1_CW16_segment1.wav -> B1_CW16.wav
# Rinominato: B1_CW17_segment1.wav -> B1_CW17.wav
# Rinominato: B1_CW18_segment1.wav -> B1_CW18.wav
# Rinominato: B1_CW19_segment1.wav -> B1_CW19.wav
# Rinominato: B1_CW1_segment1.wav -> B1_CW1.wav
# Rinominato: B1_CW20_segment1.wav -> B1_CW20.wav
# Rinominato: B1_CW21_segment1.wav -> B1_CW21.wav
# Rinominato: B1_CW22_segment1.wav -> B1_CW22.wav
# Rinominato: B1_CW23_segment1.wav -> B1_CW23.wav
# Rinominato: B1_CW24_segment1.wav -> B1_CW24.wav
# Rinominato: B1_CW25_segment1.wav -> B1_CW25.wav
# Rinominato: B1_CW26_segment1.wav -> B1_CW26.wav
# Rinominato: B1_CW27_segment1.wav -> B1_CW27.wav
# Rinominato: B1_CW28_segment1.wav -> B1_CW28.wav
# Rinominato: B1_CW29_segment1.wav -> B1_CW29.wav
# Rinominato: B1_CW2_segment1.wav -> B1_CW2.wav
# Rinominato: B1_CW30_segment1.wav -> B1_CW30.wav
# Rinominato: B1_CW31_segment1.wav -> B1_CW31.wav
# Rinominato: B1_CW32_segment1.wav -> B1_CW32.wav
# Rinominato: B1_CW33_segment1.wav -> B1_CW33.wav
# Rinominato: B1_CW34_segment1.wav -> B1_CW34.wav
# Rinominato: B1_CW35_segment1.wav -> B1_CW35.wav
# Rinominato: B1_CW36_segment1.wav -> B1_CW36.wav
# Rinominato: B1_CW37_segment1.wav -> B1_CW37.wav
# Rinominato: B1_CW38_segment1.wav -> B1_CW38.wav
# Rinominato: B1_CW39_segment1.wav -> B1_CW39.wav
# Rinominato: B1_CW3_segment1.wav -> B1_CW3.wav
# Rinominato: B1_CW40_segment1.wav -> B1_CW40.wav
# Rinominato: B1_CW41_segment1.wav -> B1_CW41.wav
# Rinominato: B1_CW42_segment1.wav -> B1_CW42.wav
# Rinominato: B1_CW43_segment1.wav -> B1_CW43.wav
# Rinominato: B1_CW44_segment1.wav -> B1_CW44.wav
# Rinominato: B1_CW45_segment1.wav -> B1_CW45.wav
# Rinominato: B1_CW46_segment1.wav -> B1_CW46.wav
# Rinominato: B1_CW47_segment1.wav -> B1_CW47.wav
# Rinominato: B1_CW48_segment1.wav -> B1_CW48.wav
# Rinominato: B1_CW49_segment1.wav -> B1_CW49.wav
# Rinominato: B1_CW4_segment1.wav -> B1_CW4.wav
# Rinominato: B1_CW50_segment1.wav -> B1_CW50.wav
# Rinominato: B1_CW51_segment1.wav -> B1_CW51.wav
# Rinominato: B1_CW52_segment1.wav -> B1_CW52.wav
# Rinominato: B1_CW53_segment1.wav -> B1_CW53.wav
# Rinominato: B1_CW54_segment1.wav -> B1_CW54.wav
# Rinominato: B1_CW55_segment1.wav -> B1_CW55.wav
# Rinominato: B1_CW56_segment1.wav -> B1_CW56.wav
# Rinominato: B1_CW57_segment1.wav -> B1_CW57.wav
# Rinominato: B1_CW58_segment1.wav -> B1_CW58.wav
# Rinominato: B1_CW59_segment1.wav -> B1_CW59.wav
# Rinominato: B1_CW5_segment1.wav -> B1_CW5.wav
# Rinominato: B1_CW60_segment1.wav -> B1_CW60.wav
# Rinominato: B1_CW61_segment1.wav -> B1_CW61.wav
# Rinominato: B1_CW62_segment1.wav -> B1_CW62.wav
# Rinominato: B1_CW63_segment1.wav -> B1_CW63.wav
# Rinominato: B1_CW64_segment1.wav -> B1_CW64.wav
# Rinominato: B1_CW65_segment1.wav -> B1_CW65.wav
# Rinominato: B1_CW66_segment1.wav -> B1_CW66.wav
# Rinominato: B1_CW67_segment1.wav -> B1_CW67.wav
# Rinominato: B1_CW68_segment1.wav -> B1_CW68.wav
# Rinominato: B1_CW69_segment1.wav -> B1_CW69.wav
# Rinominato: B1_CW6_segment1.wav -> B1_CW6.wav
# Rinominato: B1_CW70_segment1.wav -> B1_CW70.wav
# Rinominato: B1_CW71_segment1.wav -> B1_CW71.wav
# Rinominato: B1_CW72_segment1.wav -> B1_CW72.wav
# Rinominato: B1_CW73_segment1.wav -> B1_CW73.wav
# Rinominato: B1_CW74_segment1.wav -> B1_CW74.wav
# Rinominato: B1_CW75_segment1.wav -> B1_CW75.wav
# Rinominato: B1_CW76_segment1.wav -> B1_CW76.wav
# Rinominato: B1_CW77_segment1.wav -> B1_CW77.wav
# Rinominato: B1_CW78_segment1.wav -> B1_CW78.wav
# Rinominato: B1_CW79_segment1.wav -> B1_CW79.wav
# Rinominato: B1_CW7_segment1.wav -> B1_CW7.wav
# Rinominato: B1_CW80_segment1.wav -> B1_CW80.wav
# Rinominato: B1_CW81_segment1.wav -> B1_CW81.wav
# Rinominato: B1_CW82_segment1.wav -> B1_CW82.wav
# Rinominato: B1_CW83_segment1.wav -> B1_CW83.wav
# Rinominato: B1_CW84_segment1.wav -> B1_CW84.wav
# Rinominato: B1_CW85_segment1.wav -> B1_CW85.wav
# Rinominato: B1_CW86_segment1.wav -> B1_CW86.wav
# Rinominato: B1_CW87_segment1.wav -> B1_CW87.wav
# Rinominato: B1_CW88_segment1.wav -> B1_CW88.wav
# Rinominato: B1_CW89_segment1.wav -> B1_CW89.wav
# Rinominato: B1_CW8_segment1.wav -> B1_CW8.wav
# Rinominato: B1_CW90_segment1.wav -> B1_CW90.wav
# Rinominato: B1_CW91_segment1.wav -> B1_CW91.wav
# Rinominato: B1_CW92_segment1.wav -> B1_CW92.wav
# Rinominato: B1_CW93_segment1.wav -> B1_CW93.wav
# Rinominato: B1_CW94_segment1.wav -> B1_CW94.wav
# Rinominato: B1_CW95_segment1.wav -> B1_CW95.wav
# Rinominato: B1_CW96_segment1.wav -> B1_CW96.wav
# Rinominato: B1_CW97_segment1.wav -> B1_CW97.wav
# Rinominato: B1_CW98_segment1.wav -> B1_CW98.wav
# Rinominato: B1_CW99_segment1.wav -> B1_CW99.wav
# Rinominato: B1_CW9_segment1.wav -> B1_CW9.wav
# Rinominato: B1_D0_segment1.wav -> B1_D0.wav
# Rinominato: B1_D1_segment1.wav -> B1_D1.wav
# Rinominato: B1_D2_segment1.wav -> B1_D2.wav
# Rinominato: B1_D3_segment1.wav -> B1_D3.wav
# Rinominato: B1_D4_segment1.wav -> B1_D4.wav
# Rinominato: B1_D5_segment1.wav -> B1_D5.wav
# Rinominato: B1_D6_segment1.wav -> B1_D6.wav
# Rinominato: B1_D7_segment1.wav -> B1_D7.wav
# Rinominato: B1_D8_segment1.wav -> B1_D8.wav
# Rinominato: B1_D9_segment1.wav -> B1_D9.wav
# Rinominato: B1_LA_segment1.wav -> B1_LA.wav
# Rinominato: B1_LB_segment1.wav -> B1_LB.wav
# Rinominato: B1_LC_segment1.wav -> B1_LC.wav
# Rinominato: B1_LD_segment1.wav -> B1_LD.wav
# Rinominato: B1_LE_segment1.wav -> B1_LE.wav
# Rinominato: B1_LF_segment1.wav -> B1_LF.wav
# Rinominato: B1_LG_segment1.wav -> B1_LG.wav
# Rinominato: B1_LH_segment1.wav -> B1_LH.wav
# Rinominato: B1_LI_segment1.wav -> B1_LI.wav
# Rinominato: B1_LJ_segment1.wav -> B1_LJ.wav
# Rinominato: B1_LK_segment1.wav -> B1_LK.wav
# Rinominato: B1_LL_segment1.wav -> B1_LL.wav
# Rinominato: B1_LM_segment1.wav -> B1_LM.wav
# Rinominato: B1_LN_segment1.wav -> B1_LN.wav
# Rinominato: B1_LO_segment1.wav -> B1_LO.wav
# Rinominato: B1_LP_segment1.wav -> B1_LP.wav
# Rinominato: B1_LQ_segment1.wav -> B1_LQ.wav
# Rinominato: B1_LR_segment1.wav -> B1_LR.wav
# Rinominato: B1_LS_segment1.wav -> B1_LS.wav
# Rinominato: B1_LT_segment1.wav -> B1_LT.wav
# Rinominato: B1_LU_segment1.wav -> B1_LU.wav
# Rinominato: B1_LV_segment1.wav -> B1_LV.wav
# Rinominato: B1_LW_segment1.wav -> B1_LW.wav
# Rinominato: B1_LX_segment1.wav -> B1_LX.wav
# Rinominato: B1_LY_segment1.wav -> B1_LY.wav
# Rinominato: B1_LZ_segment1.wav -> B1_LZ.wav
# Rinominato: B1_UW100_segment1.wav -> B1_UW100.wav
# Rinominato: B1_UW10_segment1.wav -> B1_UW10.wav
# Rinominato: B1_UW11_segment1.wav -> B1_UW11.wav
# Rinominato: B1_UW12_segment1.wav -> B1_UW12.wav
# Rinominato: B1_UW13_segment1.wav -> B1_UW13.wav
# Rinominato: B1_UW14_segment1.wav -> B1_UW14.wav
# Rinominato: B1_UW15_segment1.wav -> B1_UW15.wav
# Rinominato: B1_UW16_segment1.wav -> B1_UW16.wav
# Rinominato: B1_UW17_segment1.wav -> B1_UW17.wav
# Rinominato: B1_UW18_segment1.wav -> B1_UW18.wav
# Rinominato: B1_UW19_segment1.wav -> B1_UW19.wav
# Rinominato: B1_UW1_segment1.wav -> B1_UW1.wav
# Rinominato: B1_UW20_segment1.wav -> B1_UW20.wav
# Rinominato: B1_UW21_segment1.wav -> B1_UW21.wav
# Rinominato: B1_UW22_segment1.wav -> B1_UW22.wav
# Rinominato: B1_UW23_segment1.wav -> B1_UW23.wav
# Rinominato: B1_UW24_segment1.wav -> B1_UW24.wav
# Rinominato: B1_UW25_segment1.wav -> B1_UW25.wav
# Rinominato: B1_UW26_segment1.wav -> B1_UW26.wav
# Rinominato: B1_UW27_segment1.wav -> B1_UW27.wav
# Rinominato: B1_UW28_segment1.wav -> B1_UW28.wav
# Rinominato: B1_UW29_segment1.wav -> B1_UW29.wav
# Rinominato: B1_UW2_segment1.wav -> B1_UW2.wav
# Rinominato: B1_UW30_segment1.wav -> B1_UW30.wav
# Rinominato: B1_UW31_segment1.wav -> B1_UW31.wav
# Rinominato: B1_UW32_segment1.wav -> B1_UW32.wav
# Rinominato: B1_UW33_segment1.wav -> B1_UW33.wav
# Rinominato: B1_UW34_segment1.wav -> B1_UW34.wav
# Rinominato: B1_UW35_segment1.wav -> B1_UW35.wav
# Rinominato: B1_UW36_segment1.wav -> B1_UW36.wav
# Rinominato: B1_UW37_segment1.wav -> B1_UW37.wav
# Rinominato: B1_UW38_segment1.wav -> B1_UW38.wav
# Rinominato: B1_UW39_segment1.wav -> B1_UW39.wav
# Rinominato: B1_UW3_segment1.wav -> B1_UW3.wav
# Rinominato: B1_UW40_segment1.wav -> B1_UW40.wav
# Rinominato: B1_UW41_segment1.wav -> B1_UW41.wav
# Rinominato: B1_UW42_segment1.wav -> B1_UW42.wav
# Rinominato: B1_UW43_segment1.wav -> B1_UW43.wav
# Rinominato: B1_UW44_segment1.wav -> B1_UW44.wav
# Rinominato: B1_UW45_segment1.wav -> B1_UW45.wav
# Rinominato: B1_UW46_segment1.wav -> B1_UW46.wav
# Rinominato: B1_UW47_segment1.wav -> B1_UW47.wav
# Rinominato: B1_UW48_segment1.wav -> B1_UW48.wav
# Rinominato: B1_UW49_segment1.wav -> B1_UW49.wav
# Rinominato: B1_UW4_segment1.wav -> B1_UW4.wav
# Rinominato: B1_UW50_segment1.wav -> B1_UW50.wav
# Rinominato: B1_UW51_segment1.wav -> B1_UW51.wav
# Rinominato: B1_UW52_segment1.wav -> B1_UW52.wav
# Rinominato: B1_UW53_segment1.wav -> B1_UW53.wav
# Rinominato: B1_UW54_segment1.wav -> B1_UW54.wav
# Rinominato: B1_UW55_segment1.wav -> B1_UW55.wav
# Rinominato: B1_UW56_segment1.wav -> B1_UW56.wav
# Rinominato: B1_UW57_segment1.wav -> B1_UW57.wav
# Rinominato: B1_UW58_segment1.wav -> B1_UW58.wav
# Rinominato: B1_UW59_segment1.wav -> B1_UW59.wav
# Rinominato: B1_UW5_segment1.wav -> B1_UW5.wav
# Rinominato: B1_UW60_segment1.wav -> B1_UW60.wav
# Rinominato: B1_UW61_segment1.wav -> B1_UW61.wav
# Rinominato: B1_UW62_segment1.wav -> B1_UW62.wav
# Rinominato: B1_UW63_segment1.wav -> B1_UW63.wav
# Rinominato: B1_UW64_segment1.wav -> B1_UW64.wav
# Rinominato: B1_UW65_segment1.wav -> B1_UW65.wav
# Rinominato: B1_UW66_segment1.wav -> B1_UW66.wav
# Rinominato: B1_UW67_segment1.wav -> B1_UW67.wav
# Rinominato: B1_UW68_segment1.wav -> B1_UW68.wav
# Rinominato: B1_UW69_segment1.wav -> B1_UW69.wav
# Rinominato: B1_UW6_segment1.wav -> B1_UW6.wav
# Rinominato: B1_UW70_segment1.wav -> B1_UW70.wav
# Rinominato: B1_UW71_segment1.wav -> B1_UW71.wav
# Rinominato: B1_UW72_segment1.wav -> B1_UW72.wav
# Rinominato: B1_UW73_segment1.wav -> B1_UW73.wav
# Rinominato: B1_UW74_segment1.wav -> B1_UW74.wav
# Rinominato: B1_UW75_segment1.wav -> B1_UW75.wav
# Rinominato: B1_UW76_segment1.wav -> B1_UW76.wav
# Rinominato: B1_UW77_segment1.wav -> B1_UW77.wav
# Rinominato: B1_UW78_segment1.wav -> B1_UW78.wav
# Rinominato: B1_UW79_segment1.wav -> B1_UW79.wav
# Rinominato: B1_UW7_segment1.wav -> B1_UW7.wav
# Rinominato: B1_UW80_segment1.wav -> B1_UW80.wav
# Rinominato: B1_UW81_segment1.wav -> B1_UW81.wav
# Rinominato: B1_UW82_segment1.wav -> B1_UW82.wav
# Rinominato: B1_UW83_segment1.wav -> B1_UW83.wav
# Rinominato: B1_UW84_segment1.wav -> B1_UW84.wav
# Rinominato: B1_UW85_segment1.wav -> B1_UW85.wav
# Rinominato: B1_UW86_segment1.wav -> B1_UW86.wav
# Rinominato: B1_UW87_segment1.wav -> B1_UW87.wav
# Rinominato: B1_UW88_segment1.wav -> B1_UW88.wav
# Rinominato: B1_UW89_segment1.wav -> B1_UW89.wav
# Rinominato: B1_UW8_segment1.wav -> B1_UW8.wav
# Rinominato: B1_UW90_segment1.wav -> B1_UW90.wav
# Rinominato: B1_UW91_segment1.wav -> B1_UW91.wav
# Rinominato: B1_UW92_segment1.wav -> B1_UW92.wav
# Rinominato: B1_UW93_segment1.wav -> B1_UW93.wav
# Rinominato: B1_UW94_segment1.wav -> B1_UW94.wav
# Rinominato: B1_UW95_segment1.wav -> B1_UW95.wav
# Rinominato: B1_UW96_segment1.wav -> B1_UW96.wav
# Rinominato: B1_UW97_segment1.wav -> B1_UW97.wav
# Rinominato: B1_UW98_segment1.wav -> B1_UW98.wav
# Rinominato: B1_UW99_segment1.wav -> B1_UW99.wav
# Rinominato: B1_UW9_segment1.wav -> B1_UW9.wav
# Rinominato: B2_C10_segment1.wav -> B2_C10.wav
# Rinominato: B2_C11_segment1.wav -> B2_C11.wav
# Rinominato: B2_C12_segment1.wav -> B2_C12.wav
# Rinominato: B2_C13_segment1.wav -> B2_C13.wav
# Rinominato: B2_C14_segment1.wav -> B2_C14.wav
# Rinominato: B2_C15_segment1.wav -> B2_C15.wav
# Rinominato: B2_C16_segment1.wav -> B2_C16.wav
# Rinominato: B2_C17_segment1.wav -> B2_C17.wav
# Rinominato: B2_C18_segment1.wav -> B2_C18.wav
# Rinominato: B2_C19_segment1.wav -> B2_C19.wav
# Rinominato: B2_C1_segment1.wav -> B2_C1.wav
# Rinominato: B2_C2_segment1.wav -> B2_C2.wav
# Rinominato: B2_C3_segment1.wav -> B2_C3.wav
# Rinominato: B2_C4_segment1.wav -> B2_C4.wav
# Rinominato: B2_C5_segment1.wav -> B2_C5.wav
# Rinominato: B2_C6_segment1.wav -> B2_C6.wav
# Rinominato: B2_C7_segment1.wav -> B2_C7.wav
# Rinominato: B2_C8_segment1.wav -> B2_C8.wav
# Rinominato: B2_C9_segment1.wav -> B2_C9.wav
# Rinominato: B2_CW100_segment1.wav -> B2_CW100.wav
# Rinominato: B2_CW10_segment1.wav -> B2_CW10.wav
# Rinominato: B2_CW11_segment1.wav -> B2_CW11.wav
# Rinominato: B2_CW12_segment1.wav -> B2_CW12.wav
# Rinominato: B2_CW13_segment1.wav -> B2_CW13.wav
# Rinominato: B2_CW14_segment1.wav -> B2_CW14.wav
# Rinominato: B2_CW15_segment1.wav -> B2_CW15.wav
# Rinominato: B2_CW16_segment1.wav -> B2_CW16.wav
# Rinominato: B2_CW17_segment1.wav -> B2_CW17.wav
# Rinominato: B2_CW18_segment1.wav -> B2_CW18.wav
# Rinominato: B2_CW19_segment1.wav -> B2_CW19.wav
# Rinominato: B2_CW1_segment1.wav -> B2_CW1.wav
# Rinominato: B2_CW20_segment1.wav -> B2_CW20.wav
# Rinominato: B2_CW21_segment1.wav -> B2_CW21.wav
# Rinominato: B2_CW22_segment1.wav -> B2_CW22.wav
# Rinominato: B2_CW23_segment1.wav -> B2_CW23.wav
# Rinominato: B2_CW24_segment1.wav -> B2_CW24.wav
# Rinominato: B2_CW25_segment1.wav -> B2_CW25.wav
# Rinominato: B2_CW26_segment1.wav -> B2_CW26.wav
# Rinominato: B2_CW27_segment1.wav -> B2_CW27.wav
# Rinominato: B2_CW28_segment1.wav -> B2_CW28.wav
# Rinominato: B2_CW29_segment1.wav -> B2_CW29.wav
# Rinominato: B2_CW2_segment1.wav -> B2_CW2.wav
# Rinominato: B2_CW30_segment1.wav -> B2_CW30.wav
# Rinominato: B2_CW31_segment1.wav -> B2_CW31.wav
# Rinominato: B2_CW32_segment1.wav -> B2_CW32.wav
# Rinominato: B2_CW33_segment1.wav -> B2_CW33.wav
# Rinominato: B2_CW34_segment1.wav -> B2_CW34.wav
# Rinominato: B2_CW35_segment1.wav -> B2_CW35.wav
# Rinominato: B2_CW36_segment1.wav -> B2_CW36.wav
# Rinominato: B2_CW37_segment1.wav -> B2_CW37.wav
# Rinominato: B2_CW38_segment1.wav -> B2_CW38.wav
# Rinominato: B2_CW39_segment1.wav -> B2_CW39.wav
# Rinominato: B2_CW3_segment1.wav -> B2_CW3.wav
# Rinominato: B2_CW40_segment1.wav -> B2_CW40.wav
# Rinominato: B2_CW41_segment1.wav -> B2_CW41.wav
# Rinominato: B2_CW42_segment1.wav -> B2_CW42.wav
# Rinominato: B2_CW43_segment1.wav -> B2_CW43.wav
# Rinominato: B2_CW44_segment1.wav -> B2_CW44.wav
# Rinominato: B2_CW45_segment1.wav -> B2_CW45.wav
# Rinominato: B2_CW46_segment1.wav -> B2_CW46.wav
# Rinominato: B2_CW47_segment1.wav -> B2_CW47.wav
# Rinominato: B2_CW48_segment1.wav -> B2_CW48.wav
# Rinominato: B2_CW49_segment1.wav -> B2_CW49.wav
# Rinominato: B2_CW4_segment1.wav -> B2_CW4.wav
# Rinominato: B2_CW50_segment1.wav -> B2_CW50.wav
# Rinominato: B2_CW51_segment1.wav -> B2_CW51.wav
# Rinominato: B2_CW52_segment1.wav -> B2_CW52.wav
# Rinominato: B2_CW53_segment1.wav -> B2_CW53.wav
# Rinominato: B2_CW54_segment1.wav -> B2_CW54.wav
# Rinominato: B2_CW55_segment1.wav -> B2_CW55.wav
# Rinominato: B2_CW56_segment1.wav -> B2_CW56.wav
# Rinominato: B2_CW57_segment1.wav -> B2_CW57.wav
# Rinominato: B2_CW58_segment1.wav -> B2_CW58.wav
# Rinominato: B2_CW59_segment1.wav -> B2_CW59.wav
# Rinominato: B2_CW5_segment1.wav -> B2_CW5.wav
# Rinominato: B2_CW60_segment1.wav -> B2_CW60.wav
# Rinominato: B2_CW61_segment1.wav -> B2_CW61.wav
# Rinominato: B2_CW62_segment1.wav -> B2_CW62.wav
# Rinominato: B2_CW63_segment1.wav -> B2_CW63.wav
# Rinominato: B2_CW64_segment1.wav -> B2_CW64.wav
# Rinominato: B2_CW65_segment1.wav -> B2_CW65.wav
# Rinominato: B2_CW66_segment1.wav -> B2_CW66.wav
# Rinominato: B2_CW67_segment1.wav -> B2_CW67.wav
# Rinominato: B2_CW68_segment1.wav -> B2_CW68.wav
# Rinominato: B2_CW69_segment1.wav -> B2_CW69.wav
# Rinominato: B2_CW6_segment1.wav -> B2_CW6.wav
# Rinominato: B2_CW70_segment1.wav -> B2_CW70.wav
# Rinominato: B2_CW71_segment1.wav -> B2_CW71.wav
# Rinominato: B2_CW72_segment1.wav -> B2_CW72.wav
# Rinominato: B2_CW73_segment1.wav -> B2_CW73.wav
# Rinominato: B2_CW74_segment1.wav -> B2_CW74.wav
# Rinominato: B2_CW75_segment1.wav -> B2_CW75.wav
# Rinominato: B2_CW76_segment1.wav -> B2_CW76.wav
# Rinominato: B2_CW77_segment1.wav -> B2_CW77.wav
# Rinominato: B2_CW78_segment1.wav -> B2_CW78.wav
# Rinominato: B2_CW79_segment1.wav -> B2_CW79.wav
# Rinominato: B2_CW7_segment1.wav -> B2_CW7.wav
# Rinominato: B2_CW80_segment1.wav -> B2_CW80.wav
# Rinominato: B2_CW81_segment1.wav -> B2_CW81.wav
# Rinominato: B2_CW82_segment1.wav -> B2_CW82.wav
# Rinominato: B2_CW83_segment1.wav -> B2_CW83.wav
# Rinominato: B2_CW84_segment1.wav -> B2_CW84.wav
# Rinominato: B2_CW85_segment1.wav -> B2_CW85.wav
# Rinominato: B2_CW86_segment1.wav -> B2_CW86.wav
# Rinominato: B2_CW87_segment1.wav -> B2_CW87.wav
# Rinominato: B2_CW88_segment1.wav -> B2_CW88.wav
# Rinominato: B2_CW89_segment1.wav -> B2_CW89.wav
# Rinominato: B2_CW8_segment1.wav -> B2_CW8.wav
# Rinominato: B2_CW90_segment1.wav -> B2_CW90.wav
# Rinominato: B2_CW91_segment1.wav -> B2_CW91.wav
# Rinominato: B2_CW92_segment1.wav -> B2_CW92.wav
# Rinominato: B2_CW93_segment1.wav -> B2_CW93.wav
# Rinominato: B2_CW94_segment1.wav -> B2_CW94.wav
# Rinominato: B2_CW95_segment1.wav -> B2_CW95.wav
# Rinominato: B2_CW96_segment1.wav -> B2_CW96.wav
# Rinominato: B2_CW97_segment1.wav -> B2_CW97.wav
# Rinominato: B2_CW98_segment1.wav -> B2_CW98.wav
# Rinominato: B2_CW99_segment1.wav -> B2_CW99.wav
# Rinominato: B2_CW9_segment1.wav -> B2_CW9.wav
# Rinominato: B2_D0_segment1.wav -> B2_D0.wav
# Rinominato: B2_D1_segment1.wav -> B2_D1.wav
# Rinominato: B2_D2_segment1.wav -> B2_D2.wav
# Rinominato: B2_D3_segment1.wav -> B2_D3.wav
# Rinominato: B2_D4_segment1.wav -> B2_D4.wav
# Rinominato: B2_D5_segment1.wav -> B2_D5.wav
# Rinominato: B2_D6_segment1.wav -> B2_D6.wav
# Rinominato: B2_D7_segment1.wav -> B2_D7.wav
# Rinominato: B2_D8_segment1.wav -> B2_D8.wav
# Rinominato: B2_D9_segment1.wav -> B2_D9.wav
# Rinominato: B2_LA_segment1.wav -> B2_LA.wav
# Rinominato: B2_LB_segment1.wav -> B2_LB.wav
# Rinominato: B2_LC_segment1.wav -> B2_LC.wav
# Rinominato: B2_LD_segment1.wav -> B2_LD.wav
# Rinominato: B2_LE_segment1.wav -> B2_LE.wav
# Rinominato: B2_LF_segment1.wav -> B2_LF.wav
# Rinominato: B2_LG_segment1.wav -> B2_LG.wav
# Rinominato: B2_LH_segment1.wav -> B2_LH.wav
# Rinominato: B2_LI_segment1.wav -> B2_LI.wav
# Rinominato: B2_LJ_segment1.wav -> B2_LJ.wav
# Rinominato: B2_LK_segment1.wav -> B2_LK.wav
# Rinominato: B2_LL_segment1.wav -> B2_LL.wav
# Rinominato: B2_LM_segment1.wav -> B2_LM.wav
# Rinominato: B2_LN_segment1.wav -> B2_LN.wav
# Rinominato: B2_LO_segment1.wav -> B2_LO.wav
# Rinominato: B2_LP_segment1.wav -> B2_LP.wav
# Rinominato: B2_LQ_segment1.wav -> B2_LQ.wav
# Rinominato: B2_LR_segment1.wav -> B2_LR.wav
# Rinominato: B2_LS_segment1.wav -> B2_LS.wav
# Rinominato: B2_LT_segment1.wav -> B2_LT.wav
# Rinominato: B2_LU_segment1.wav -> B2_LU.wav
# Rinominato: B2_LV_segment1.wav -> B2_LV.wav
# Rinominato: B2_LW_segment1.wav -> B2_LW.wav
# Rinominato: B2_LX_segment1.wav -> B2_LX.wav
# Rinominato: B2_LY_segment1.wav -> B2_LY.wav
# Rinominato: B2_LZ_segment1.wav -> B2_LZ.wav
# Rinominato: B2_UW100_segment1.wav -> B2_UW100.wav
# Rinominato: B2_UW10_segment1.wav -> B2_UW10.wav
# Rinominato: B2_UW11_segment1.wav -> B2_UW11.wav
# Rinominato: B2_UW12_segment1.wav -> B2_UW12.wav
# Rinominato: B2_UW13_segment1.wav -> B2_UW13.wav
# Rinominato: B2_UW14_segment1.wav -> B2_UW14.wav
# Rinominato: B2_UW15_segment1.wav -> B2_UW15.wav
# Rinominato: B2_UW16_segment1.wav -> B2_UW16.wav
# Rinominato: B2_UW17_segment1.wav -> B2_UW17.wav
# Rinominato: B2_UW18_segment1.wav -> B2_UW18.wav
# Rinominato: B2_UW19_segment1.wav -> B2_UW19.wav
# Rinominato: B2_UW1_segment1.wav -> B2_UW1.wav
# Rinominato: B2_UW20_segment1.wav -> B2_UW20.wav
# Rinominato: B2_UW21_segment1.wav -> B2_UW21.wav
# Rinominato: B2_UW22_segment1.wav -> B2_UW22.wav
# Rinominato: B2_UW23_segment1.wav -> B2_UW23.wav
# Rinominato: B2_UW24_segment1.wav -> B2_UW24.wav
# Rinominato: B2_UW25_segment1.wav -> B2_UW25.wav
# Rinominato: B2_UW26_segment1.wav -> B2_UW26.wav
# Rinominato: B2_UW27_segment1.wav -> B2_UW27.wav
# Rinominato: B2_UW28_segment1.wav -> B2_UW28.wav
# Rinominato: B2_UW29_segment1.wav -> B2_UW29.wav
# Rinominato: B2_UW2_segment1.wav -> B2_UW2.wav
# Rinominato: B2_UW30_segment1.wav -> B2_UW30.wav
# Rinominato: B2_UW31_segment1.wav -> B2_UW31.wav
# Rinominato: B2_UW32_segment1.wav -> B2_UW32.wav
# Rinominato: B2_UW33_segment1.wav -> B2_UW33.wav
# Rinominato: B2_UW34_segment1.wav -> B2_UW34.wav
# Rinominato: B2_UW35_segment1.wav -> B2_UW35.wav
# Rinominato: B2_UW36_segment1.wav -> B2_UW36.wav
# Rinominato: B2_UW37_segment1.wav -> B2_UW37.wav
# Rinominato: B2_UW38_segment1.wav -> B2_UW38.wav
# Rinominato: B2_UW39_segment1.wav -> B2_UW39.wav
# Rinominato: B2_UW3_segment1.wav -> B2_UW3.wav
# Rinominato: B2_UW40_segment1.wav -> B2_UW40.wav
# Rinominato: B2_UW41_segment1.wav -> B2_UW41.wav
# Rinominato: B2_UW42_segment1.wav -> B2_UW42.wav
# Rinominato: B2_UW43_segment1.wav -> B2_UW43.wav
# Rinominato: B2_UW44_segment1.wav -> B2_UW44.wav
# Rinominato: B2_UW45_segment1.wav -> B2_UW45.wav
# Rinominato: B2_UW46_segment1.wav -> B2_UW46.wav
# Rinominato: B2_UW47_segment1.wav -> B2_UW47.wav
# Rinominato: B2_UW48_segment1.wav -> B2_UW48.wav
# Rinominato: B2_UW49_segment1.wav -> B2_UW49.wav
# Rinominato: B2_UW4_segment1.wav -> B2_UW4.wav
# Rinominato: B2_UW50_segment1.wav -> B2_UW50.wav
# Rinominato: B2_UW51_segment1.wav -> B2_UW51.wav
# Rinominato: B2_UW52_segment1.wav -> B2_UW52.wav
# Rinominato: B2_UW53_segment1.wav -> B2_UW53.wav
# Rinominato: B2_UW54_segment1.wav -> B2_UW54.wav
# Rinominato: B2_UW55_segment1.wav -> B2_UW55.wav
# Rinominato: B2_UW56_segment1.wav -> B2_UW56.wav
# Rinominato: B2_UW57_segment1.wav -> B2_UW57.wav
# Rinominato: B2_UW58_segment1.wav -> B2_UW58.wav
# Rinominato: B2_UW59_segment1.wav -> B2_UW59.wav
# Rinominato: B2_UW5_segment1.wav -> B2_UW5.wav
# Rinominato: B2_UW60_segment1.wav -> B2_UW60.wav
# Rinominato: B2_UW61_segment1.wav -> B2_UW61.wav
# Rinominato: B2_UW62_segment1.wav -> B2_UW62.wav
# Rinominato: B2_UW63_segment1.wav -> B2_UW63.wav
# Rinominato: B2_UW64_segment1.wav -> B2_UW64.wav
# Rinominato: B2_UW65_segment1.wav -> B2_UW65.wav
# Rinominato: B2_UW66_segment1.wav -> B2_UW66.wav
# Rinominato: B2_UW67_segment1.wav -> B2_UW67.wav
# Rinominato: B2_UW68_segment1.wav -> B2_UW68.wav
# Rinominato: B2_UW69_segment1.wav -> B2_UW69.wav
# Rinominato: B2_UW6_segment1.wav -> B2_UW6.wav
# Rinominato: B2_UW70_segment1.wav -> B2_UW70.wav
# Rinominato: B2_UW71_segment1.wav -> B2_UW71.wav
# Rinominato: B2_UW72_segment1.wav -> B2_UW72.wav
# Rinominato: B2_UW73_segment1.wav -> B2_UW73.wav
# Rinominato: B2_UW74_segment1.wav -> B2_UW74.wav
# Rinominato: B2_UW75_segment1.wav -> B2_UW75.wav
# Rinominato: B2_UW76_segment1.wav -> B2_UW76.wav
# Rinominato: B2_UW77_segment1.wav -> B2_UW77.wav
# Rinominato: B2_UW78_segment1.wav -> B2_UW78.wav
# Rinominato: B2_UW79_segment1.wav -> B2_UW79.wav
# Rinominato: B2_UW7_segment1.wav -> B2_UW7.wav
# Rinominato: B2_UW80_segment1.wav -> B2_UW80.wav
# Rinominato: B2_UW81_segment1.wav -> B2_UW81.wav
# Rinominato: B2_UW82_segment1.wav -> B2_UW82.wav
# Rinominato: B2_UW83_segment1.wav -> B2_UW83.wav
# Rinominato: B2_UW84_segment1.wav -> B2_UW84.wav
# Rinominato: B2_UW85_segment1.wav -> B2_UW85.wav
# Rinominato: B2_UW86_segment1.wav -> B2_UW86.wav
# Rinominato: B2_UW87_segment1.wav -> B2_UW87.wav
# Rinominato: B2_UW88_segment1.wav -> B2_UW88.wav
# Rinominato: B2_UW89_segment1.wav -> B2_UW89.wav
# Rinominato: B2_UW8_segment1.wav -> B2_UW8.wav
# Rinominato: B2_UW90_segment1.wav -> B2_UW90.wav
# Rinominato: B2_UW91_segment1.wav -> B2_UW91.wav
# Rinominato: B2_UW92_segment1.wav -> B2_UW92.wav
# Rinominato: B2_UW93_segment1.wav -> B2_UW93.wav
# Rinominato: B2_UW94_segment1.wav -> B2_UW94.wav
# Rinominato: B2_UW95_segment1.wav -> B2_UW95.wav
# Rinominato: B2_UW96_segment1.wav -> B2_UW96.wav
# Rinominato: B2_UW97_segment1.wav -> B2_UW97.wav
# Rinominato: B2_UW98_segment1.wav -> B2_UW98.wav
# Rinominato: B2_UW99_segment1.wav -> B2_UW99.wav
# Rinominato: B2_UW9_segment1.wav -> B2_UW9.wav
# Rinominato: B3_C10_segment1.wav -> B3_C10.wav
# Rinominato: B3_C11_segment1.wav -> B3_C11.wav
# Rinominato: B3_C12_segment1.wav -> B3_C12.wav
# Rinominato: B3_C13_segment1.wav -> B3_C13.wav
# Rinominato: B3_C14_segment1.wav -> B3_C14.wav
# Rinominato: B3_C15_segment1.wav -> B3_C15.wav
# Rinominato: B3_C16_segment1.wav -> B3_C16.wav
# Rinominato: B3_C17_segment1.wav -> B3_C17.wav
# Rinominato: B3_C18_segment1.wav -> B3_C18.wav
# Rinominato: B3_C19_segment1.wav -> B3_C19.wav
# Rinominato: B3_C1_segment1.wav -> B3_C1.wav
# Rinominato: B3_C2_segment1.wav -> B3_C2.wav
# Rinominato: B3_C3_segment1.wav -> B3_C3.wav
# Rinominato: B3_C4_segment1.wav -> B3_C4.wav
# Rinominato: B3_C5_segment1.wav -> B3_C5.wav
# Rinominato: B3_C6_segment1.wav -> B3_C6.wav
# Rinominato: B3_C7_segment1.wav -> B3_C7.wav
# Rinominato: B3_C8_segment1.wav -> B3_C8.wav
# Rinominato: B3_C9_segment1.wav -> B3_C9.wav
# Rinominato: B3_CW100_segment1.wav -> B3_CW100.wav
# Rinominato: B3_CW10_segment1.wav -> B3_CW10.wav
# Rinominato: B3_CW11_segment1.wav -> B3_CW11.wav
# Rinominato: B3_CW12_segment1.wav -> B3_CW12.wav
# Rinominato: B3_CW13_segment1.wav -> B3_CW13.wav
# Rinominato: B3_CW14_segment1.wav -> B3_CW14.wav
# Rinominato: B3_CW15_segment1.wav -> B3_CW15.wav
# Rinominato: B3_CW16_segment1.wav -> B3_CW16.wav
# Rinominato: B3_CW17_segment1.wav -> B3_CW17.wav
# Rinominato: B3_CW18_segment1.wav -> B3_CW18.wav
# Rinominato: B3_CW19_segment1.wav -> B3_CW19.wav
# Rinominato: B3_CW1_segment1.wav -> B3_CW1.wav
# Rinominato: B3_CW20_segment1.wav -> B3_CW20.wav
# Rinominato: B3_CW21_segment1.wav -> B3_CW21.wav
# Rinominato: B3_CW22_segment1.wav -> B3_CW22.wav
# Rinominato: B3_CW23_segment1.wav -> B3_CW23.wav
# Rinominato: B3_CW24_segment1.wav -> B3_CW24.wav
# Rinominato: B3_CW25_segment1.wav -> B3_CW25.wav
# Rinominato: B3_CW26_segment1.wav -> B3_CW26.wav
# Rinominato: B3_CW27_segment1.wav -> B3_CW27.wav
# Rinominato: B3_CW28_segment1.wav -> B3_CW28.wav
# Rinominato: B3_CW29_segment1.wav -> B3_CW29.wav
# Rinominato: B3_CW2_segment1.wav -> B3_CW2.wav
# Rinominato: B3_CW30_segment1.wav -> B3_CW30.wav
# Rinominato: B3_CW31_segment1.wav -> B3_CW31.wav
# Rinominato: B3_CW32_segment1.wav -> B3_CW32.wav
# Rinominato: B3_CW33_segment1.wav -> B3_CW33.wav
# Rinominato: B3_CW34_segment1.wav -> B3_CW34.wav
# Rinominato: B3_CW35_segment1.wav -> B3_CW35.wav
# Rinominato: B3_CW36_segment1.wav -> B3_CW36.wav
# Rinominato: B3_CW37_segment1.wav -> B3_CW37.wav
# Rinominato: B3_CW38_segment1.wav -> B3_CW38.wav
# Rinominato: B3_CW39_segment1.wav -> B3_CW39.wav
# Rinominato: B3_CW3_segment1.wav -> B3_CW3.wav
# Rinominato: B3_CW40_segment1.wav -> B3_CW40.wav
# Rinominato: B3_CW41_segment1.wav -> B3_CW41.wav
# Rinominato: B3_CW42_segment1.wav -> B3_CW42.wav
# Rinominato: B3_CW43_segment1.wav -> B3_CW43.wav
# Rinominato: B3_CW44_segment1.wav -> B3_CW44.wav
# Rinominato: B3_CW45_segment1.wav -> B3_CW45.wav
# Rinominato: B3_CW46_segment1.wav -> B3_CW46.wav
# Rinominato: B3_CW47_segment1.wav -> B3_CW47.wav
# Rinominato: B3_CW48_segment1.wav -> B3_CW48.wav
# Rinominato: B3_CW49_segment1.wav -> B3_CW49.wav
# Rinominato: B3_CW4_segment1.wav -> B3_CW4.wav
# Rinominato: B3_CW50_segment1.wav -> B3_CW50.wav
# Rinominato: B3_CW51_segment1.wav -> B3_CW51.wav
# Rinominato: B3_CW52_segment1.wav -> B3_CW52.wav
# Rinominato: B3_CW53_segment1.wav -> B3_CW53.wav
# Rinominato: B3_CW54_segment1.wav -> B3_CW54.wav
# Rinominato: B3_CW55_segment1.wav -> B3_CW55.wav
# Rinominato: B3_CW56_segment1.wav -> B3_CW56.wav
# Rinominato: B3_CW57_segment1.wav -> B3_CW57.wav
# Rinominato: B3_CW58_segment1.wav -> B3_CW58.wav
# Rinominato: B3_CW59_segment1.wav -> B3_CW59.wav
# Rinominato: B3_CW5_segment1.wav -> B3_CW5.wav
# Rinominato: B3_CW60_segment1.wav -> B3_CW60.wav
# Rinominato: B3_CW61_segment1.wav -> B3_CW61.wav
# Rinominato: B3_CW62_segment1.wav -> B3_CW62.wav
# Rinominato: B3_CW63_segment1.wav -> B3_CW63.wav
# Rinominato: B3_CW64_segment1.wav -> B3_CW64.wav
# Rinominato: B3_CW65_segment1.wav -> B3_CW65.wav
# Rinominato: B3_CW66_segment1.wav -> B3_CW66.wav
# Rinominato: B3_CW67_segment1.wav -> B3_CW67.wav
# Rinominato: B3_CW68_segment1.wav -> B3_CW68.wav
# Rinominato: B3_CW69_segment1.wav -> B3_CW69.wav
# Rinominato: B3_CW6_segment1.wav -> B3_CW6.wav
# Rinominato: B3_CW70_segment1.wav -> B3_CW70.wav
# Rinominato: B3_CW71_segment1.wav -> B3_CW71.wav
# Rinominato: B3_CW72_segment1.wav -> B3_CW72.wav
# Rinominato: B3_CW73_segment1.wav -> B3_CW73.wav
# Rinominato: B3_CW74_segment1.wav -> B3_CW74.wav
# Rinominato: B3_CW75_segment1.wav -> B3_CW75.wav
# Rinominato: B3_CW76_segment1.wav -> B3_CW76.wav
# Rinominato: B3_CW77_segment1.wav -> B3_CW77.wav
# Rinominato: B3_CW78_segment1.wav -> B3_CW78.wav
# Rinominato: B3_CW79_segment1.wav -> B3_CW79.wav
# Rinominato: B3_CW7_segment1.wav -> B3_CW7.wav
# Rinominato: B3_CW80_segment1.wav -> B3_CW80.wav
# Rinominato: B3_CW81_segment1.wav -> B3_CW81.wav
# Rinominato: B3_CW82_segment1.wav -> B3_CW82.wav
# Rinominato: B3_CW83_segment1.wav -> B3_CW83.wav
# Rinominato: B3_CW84_segment1.wav -> B3_CW84.wav
# Rinominato: B3_CW85_segment1.wav -> B3_CW85.wav
# Rinominato: B3_CW86_segment1.wav -> B3_CW86.wav
# Rinominato: B3_CW87_segment1.wav -> B3_CW87.wav
# Rinominato: B3_CW88_segment1.wav -> B3_CW88.wav
# Rinominato: B3_CW89_segment1.wav -> B3_CW89.wav
# Rinominato: B3_CW8_segment1.wav -> B3_CW8.wav
# Rinominato: B3_CW90_segment1.wav -> B3_CW90.wav
# Rinominato: B3_CW91_segment1.wav -> B3_CW91.wav
# Rinominato: B3_CW92_segment1.wav -> B3_CW92.wav
# Rinominato: B3_CW93_segment1.wav -> B3_CW93.wav
# Rinominato: B3_CW94_segment1.wav -> B3_CW94.wav
# Rinominato: B3_CW95_segment1.wav -> B3_CW95.wav
# Rinominato: B3_CW96_segment1.wav -> B3_CW96.wav
# Rinominato: B3_CW97_segment1.wav -> B3_CW97.wav
# Rinominato: B3_CW98_segment1.wav -> B3_CW98.wav
# Rinominato: B3_CW99_segment1.wav -> B3_CW99.wav
# Rinominato: B3_CW9_segment1.wav -> B3_CW9.wav
# Rinominato: B3_D0_segment1.wav -> B3_D0.wav
# Rinominato: B3_D1_segment1.wav -> B3_D1.wav
# Rinominato: B3_D2_segment1.wav -> B3_D2.wav
# Rinominato: B3_D3_segment1.wav -> B3_D3.wav
# Rinominato: B3_D4_segment1.wav -> B3_D4.wav
# Rinominato: B3_D5_segment1.wav -> B3_D5.wav
# Rinominato: B3_D6_segment1.wav -> B3_D6.wav
# Rinominato: B3_D7_segment1.wav -> B3_D7.wav
# Rinominato: B3_D8_segment1.wav -> B3_D8.wav
# Rinominato: B3_D9_segment1.wav -> B3_D9.wav
# Rinominato: B3_LA_segment1.wav -> B3_LA.wav
# Rinominato: B3_LB_segment1.wav -> B3_LB.wav
# Rinominato: B3_LC_segment1.wav -> B3_LC.wav
# Rinominato: B3_LD_segment1.wav -> B3_LD.wav
# Rinominato: B3_LE_segment1.wav -> B3_LE.wav
# Rinominato: B3_LF_segment1.wav -> B3_LF.wav
# Rinominato: B3_LG_segment1.wav -> B3_LG.wav
# Rinominato: B3_LH_segment1.wav -> B3_LH.wav
# Rinominato: B3_LI_segment1.wav -> B3_LI.wav
# Rinominato: B3_LJ_segment1.wav -> B3_LJ.wav
# Rinominato: B3_LK_segment1.wav -> B3_LK.wav
# Rinominato: B3_LL_segment1.wav -> B3_LL.wav
# Rinominato: B3_LM_segment1.wav -> B3_LM.wav
# Rinominato: B3_LN_segment1.wav -> B3_LN.wav
# Rinominato: B3_LO_segment1.wav -> B3_LO.wav
# Rinominato: B3_LP_segment1.wav -> B3_LP.wav
# Rinominato: B3_LQ_segment1.wav -> B3_LQ.wav
# Rinominato: B3_LR_segment1.wav -> B3_LR.wav
# Rinominato: B3_LS_segment1.wav -> B3_LS.wav
# Rinominato: B3_LT_segment1.wav -> B3_LT.wav
# Rinominato: B3_LU_segment1.wav -> B3_LU.wav
# Rinominato: B3_LV_segment1.wav -> B3_LV.wav
# Rinominato: B3_LW_segment1.wav -> B3_LW.wav
# Rinominato: B3_LX_segment1.wav -> B3_LX.wav
# Rinominato: B3_LY_segment1.wav -> B3_LY.wav
# Rinominato: B3_LZ_segment1.wav -> B3_LZ.wav
# Rinominato: B3_UW100_segment1.wav -> B3_UW100.wav
# Rinominato: B3_UW10_segment1.wav -> B3_UW10.wav
# Rinominato: B3_UW11_segment1.wav -> B3_UW11.wav
# Rinominato: B3_UW12_segment1.wav -> B3_UW12.wav
# Rinominato: B3_UW13_segment1.wav -> B3_UW13.wav
# Rinominato: B3_UW14_segment1.wav -> B3_UW14.wav
# Rinominato: B3_UW15_segment1.wav -> B3_UW15.wav
# Rinominato: B3_UW16_segment1.wav -> B3_UW16.wav
# Rinominato: B3_UW17_segment1.wav -> B3_UW17.wav
# Rinominato: B3_UW18_segment1.wav -> B3_UW18.wav
# Rinominato: B3_UW19_segment1.wav -> B3_UW19.wav
# Rinominato: B3_UW1_segment1.wav -> B3_UW1.wav
# Rinominato: B3_UW20_segment1.wav -> B3_UW20.wav
# Rinominato: B3_UW21_segment1.wav -> B3_UW21.wav
# Rinominato: B3_UW22_segment1.wav -> B3_UW22.wav
# Rinominato: B3_UW23_segment1.wav -> B3_UW23.wav
# Rinominato: B3_UW24_segment1.wav -> B3_UW24.wav
# Rinominato: B3_UW25_segment1.wav -> B3_UW25.wav
# Rinominato: B3_UW26_segment1.wav -> B3_UW26.wav
# Rinominato: B3_UW27_segment1.wav -> B3_UW27.wav
# Rinominato: B3_UW28_segment1.wav -> B3_UW28.wav
# Rinominato: B3_UW29_segment1.wav -> B3_UW29.wav
# Rinominato: B3_UW2_segment1.wav -> B3_UW2.wav
# Rinominato: B3_UW30_segment1.wav -> B3_UW30.wav
# Rinominato: B3_UW31_segment1.wav -> B3_UW31.wav
# Rinominato: B3_UW32_segment1.wav -> B3_UW32.wav
# Rinominato: B3_UW33_segment1.wav -> B3_UW33.wav
# Rinominato: B3_UW34_segment1.wav -> B3_UW34.wav
# Rinominato: B3_UW35_segment1.wav -> B3_UW35.wav
# Rinominato: B3_UW36_segment1.wav -> B3_UW36.wav
# Rinominato: B3_UW37_segment1.wav -> B3_UW37.wav
# Rinominato: B3_UW38_segment1.wav -> B3_UW38.wav
# Rinominato: B3_UW39_segment1.wav -> B3_UW39.wav
# Rinominato: B3_UW3_segment1.wav -> B3_UW3.wav
# Rinominato: B3_UW40_segment1.wav -> B3_UW40.wav
# Rinominato: B3_UW41_segment1.wav -> B3_UW41.wav
# Rinominato: B3_UW42_segment1.wav -> B3_UW42.wav
# Rinominato: B3_UW43_segment1.wav -> B3_UW43.wav
# Rinominato: B3_UW44_segment1.wav -> B3_UW44.wav
# Rinominato: B3_UW45_segment1.wav -> B3_UW45.wav
# Rinominato: B3_UW46_segment1.wav -> B3_UW46.wav
# Rinominato: B3_UW47_segment1.wav -> B3_UW47.wav
# Rinominato: B3_UW48_segment1.wav -> B3_UW48.wav
# Rinominato: B3_UW49_segment1.wav -> B3_UW49.wav
# Rinominato: B3_UW4_segment1.wav -> B3_UW4.wav
# Rinominato: B3_UW50_segment1.wav -> B3_UW50.wav
# Rinominato: B3_UW51_segment1.wav -> B3_UW51.wav
# Rinominato: B3_UW52_segment1.wav -> B3_UW52.wav
# Rinominato: B3_UW53_segment1.wav -> B3_UW53.wav
# Rinominato: B3_UW54_segment1.wav -> B3_UW54.wav
# Rinominato: B3_UW55_segment1.wav -> B3_UW55.wav
# Rinominato: B3_UW56_segment1.wav -> B3_UW56.wav
# Rinominato: B3_UW57_segment1.wav -> B3_UW57.wav
# Rinominato: B3_UW58_segment1.wav -> B3_UW58.wav
# Rinominato: B3_UW59_segment1.wav -> B3_UW59.wav
# Rinominato: B3_UW5_segment1.wav -> B3_UW5.wav
# Rinominato: B3_UW60_segment1.wav -> B3_UW60.wav
# Rinominato: B3_UW61_segment1.wav -> B3_UW61.wav
# Rinominato: B3_UW62_segment1.wav -> B3_UW62.wav
# Rinominato: B3_UW63_segment1.wav -> B3_UW63.wav
# Rinominato: B3_UW64_segment1.wav -> B3_UW64.wav
# Rinominato: B3_UW65_segment1.wav -> B3_UW65.wav
# Rinominato: B3_UW66_segment1.wav -> B3_UW66.wav
# Rinominato: B3_UW67_segment1.wav -> B3_UW67.wav
# Rinominato: B3_UW68_segment1.wav -> B3_UW68.wav
# Rinominato: B3_UW69_segment1.wav -> B3_UW69.wav
# Rinominato: B3_UW6_segment1.wav -> B3_UW6.wav
# Rinominato: B3_UW71_segment1.wav -> B3_UW71.wav
# Rinominato: B3_UW72_segment1.wav -> B3_UW72.wav
# Rinominato: B3_UW73_segment1.wav -> B3_UW73.wav
# Rinominato: B3_UW74_segment1.wav -> B3_UW74.wav
# Rinominato: B3_UW75_segment1.wav -> B3_UW75.wav
# Rinominato: B3_UW76_segment1.wav -> B3_UW76.wav
# Rinominato: B3_UW77_segment1.wav -> B3_UW77.wav
# Rinominato: B3_UW78_segment1.wav -> B3_UW78.wav
# Rinominato: B3_UW79_segment1.wav -> B3_UW79.wav
# Rinominato: B3_UW7_segment1.wav -> B3_UW7.wav
# Rinominato: B3_UW80_segment1.wav -> B3_UW80.wav
# Rinominato: B3_UW81_segment1.wav -> B3_UW81.wav
# Rinominato: B3_UW82_segment1.wav -> B3_UW82.wav
# Rinominato: B3_UW83_segment1.wav -> B3_UW83.wav
# Rinominato: B3_UW84_segment1.wav -> B3_UW84.wav
# Rinominato: B3_UW85_segment1.wav -> B3_UW85.wav
# Rinominato: B3_UW86_segment1.wav -> B3_UW86.wav
# Rinominato: B3_UW87_segment1.wav -> B3_UW87.wav
# Rinominato: B3_UW88_segment1.wav -> B3_UW88.wav
# Rinominato: B3_UW89_segment1.wav -> B3_UW89.wav
# Rinominato: B3_UW8_segment1.wav -> B3_UW8.wav
# Rinominato: B3_UW90_segment1.wav -> B3_UW90.wav
# Rinominato: B3_UW91_segment1.wav -> B3_UW91.wav
# Rinominato: B3_UW92_segment1.wav -> B3_UW92.wav
# Rinominato: B3_UW93_segment1.wav -> B3_UW93.wav
# Rinominato: B3_UW94_segment1.wav -> B3_UW94.wav
# Rinominato: B3_UW95_segment1.wav -> B3_UW95.wav
# Rinominato: B3_UW96_segment1.wav -> B3_UW96.wav
# Rinominato: B3_UW97_segment1.wav -> B3_UW97.wav
# Rinominato: B3_UW98_segment1.wav -> B3_UW98.wav
# Rinominato: B3_UW99_segment1.wav -> B3_UW99.wav
# Rinominato: B3_UW9_segment1.wav -> B3_UW9.wav

# %%
import os
import sys
from pathlib import Path

def confronta_cartelle(cartella_a, cartella_b):
    """
    Trova i file presenti in cartella_a che non sono in cartella_b.
    
    Args:
        cartella_a (str | Path): Il percorso della prima cartella.
        cartella_b (str | Path): Il percorso della seconda cartella.
        
    Returns:
        list: Una lista dei nomi dei file (senza percorso) unici in cartella_a.
    """
    
    # Converto in stringhe nel caso siano oggetti Path
    cartella_a = str(cartella_a) 
    cartella_b = str(cartella_b)
    
    # --- 1. Verifica Esistenza Cartelle ---
    if not os.path.isdir(cartella_a):
        print(f"ERRORE: La cartella A '{cartella_a}' non esiste o non è una cartella.")
        return []
    if not os.path.isdir(cartella_b):
        print(f"ERRORE: La cartella B '{cartella_b}' non esiste o non è una cartella.")
        return []

    print(f"Analisi in corso tra A: '{cartella_a}' e B: '{cartella_b}'...")
    print("-" * 40)
    
    # --- 2. Ottieni la Lista dei File ---
    # La list comprehension filtra solo i file (ignorando le sottocartelle)
    # e la conversione a set velocizza il confronto.
    try:
        files_a = {f for f in os.listdir(cartella_a) if os.path.isfile(os.path.join(cartella_a, f))}
        files_b = {f for f in os.listdir(cartella_b) if os.path.isfile(os.path.join(cartella_b, f))}

    except PermissionError as e:
        print(f"ERRORE di Permesso: Non è possibile accedere a una delle cartelle. Dettagli: {e}")
        return []
        
    # --- 3. Confronta i Set ---
    # Set difference: trova gli elementi in files_a che NON sono in files_b
    files_unici_in_a = files_a - files_b
    
    return sorted(list(files_unici_in_a))


# --- PARTE PRINCIPALE: Esempio di Utilizzo per JUPYTER NOTEBOOK ---

# **MODIFICA QUESTI PERCORSI CON LE TUE CARTELLE**
CARTELLA_UNO = Path("C:/Users/gioel/Desktop/patient_GAN_vad/patient_M05/pre_vad/M05") 
CARTELLA_DUE = Path("C:/Users/gioel/Desktop/patient_GAN_vad/patient_M05/M05") 

# Logica per sys.argv disabilitata per prevenire SystemExit nei Notebook
# Se esegui da terminale, puoi ripristinare il blocco sys.argv per accettare argomenti:
# if len(sys.argv) == 3:
#     CARTELLA_UNO = sys.argv[1]
#     CARTELLA_DUE = sys.argv[2]
# elif len(sys.argv) != 1:
#     print("Utilizzo: python nome_script.py <cartella_1> <cartella_2>")
#     sys.exit(1)

risultato = confronta_cartelle(CARTELLA_UNO, CARTELLA_DUE)

print("\n## 🔎 RISULTATO DEL CONFRONTO ##")
print("-" * 30)

if risultato:
    print(f"🚨 Trovati **{len(risultato)}** file in '{CARTELLA_UNO}' che NON sono presenti in '{CARTELLA_DUE}':")
    for file in risultato:
        print(f"- {file}")
else:
    print(f"✅ Nessun file aggiuntivo trovato. Le cartelle contengono gli stessi file (secondo il confronto A - B).")
# Out:
# Analisi in corso tra A: 'C:\Users\gioel\Desktop\patient_GAN_vad\patient_M05\pre_vad\M05' e B: 'C:\Users\gioel\Desktop\patient_GAN_vad\patient_M05\M05'...
# ----------------------------------------
#
# ## 🔎 RISULTATO DEL CONFRONTO ##
# ------------------------------
# 🚨 Trovati **5** file in 'C:\Users\gioel\Desktop\patient_GAN_vad\patient_M05\pre_vad\M05' che NON sono presenti in 'C:\Users\gioel\Desktop\patient_GAN_vad\patient_M05\M05':
# - B3_CW27.wav
# - B3_CW69.wav
# - B3_CW72.wav
# - B3_CW78.wav
# - B3_CW79.wav
